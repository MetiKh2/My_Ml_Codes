# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
data=pd.read_csv("Bengaluru_House_Data.csv")
df=data.copy()
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_94399 thead>tr>th {
#   text-align: left;
# }
# #T_94399_row0_col0, #T_94399_row1_col0, #T_94399_row2_col0, #T_94399_row3_col0, #T_94399_row4_col0, #T_94399_row5_col0, #T_94399_row6_col0, #T_94399_row7_col0, #T_94399_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_94399_row0_col1, #T_94399_row1_col1, #T_94399_row2_col1, #T_94399_row3_col1, #T_94399_row4_col1, #T_94399_row5_col1, #T_94399_row6_col1, #T_94399_row7_col1, #T_94399_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_94399_row0_col2, #T_94399_row1_col2, #T_94399_row2_col2, #T_94399_row3_col2, #T_94399_row4_col2, #T_94399_row5_col2, #T_94399_row6_col2, #T_94399_row7_col2, #T_94399_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
# ...

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft          bath       balcony         price
# ...

# %%
df['bhk']=df['size'].str.split(' ',expand=True)[0]

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price bhk
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07   2
# ...

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# bhk              object
# dtype: object

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df[~df['total_sqft'].apply(is_float)]
# Out:
#                   area_type   availability            location       size  \
# 30     Super built-up  Area         19-Dec           Yelahanka      4 BHK
# 56           Built-up  Area         20-Feb         Devanahalli  4 Bedroom
# 81           Built-up  Area         18-Oct         Hennur Road  4 Bedroom
# 122    Super built-up  Area         18-Mar              Hebbal      4 BHK
# 137    Super built-up  Area         19-Mar  8th Phase JP Nagar      2 BHK
# ...                     ...            ...                 ...        ...
# 12990  Super built-up  Area         18-May      Talaghattapura      3 BHK
# 13059  Super built-up  Area  Ready To Move              Harlur      2 BHK
# 13240  Super built-up  Area  Ready To Move         Devanahalli      1 BHK
# 13265  Super built-up  Area         20-Sep               Hoodi      2 BHK
# 13299  Super built-up  Area         18-Dec          Whitefield      4 BHK
#
#        society   total_sqft  bath  balcony    price bhk
# ...

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens)==2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('2100-2850')
# Out:
# 2475.0

# %%
df['total_sqft']=df['total_sqft'].apply(convert_sqft_to_num)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price bhk
# 0          2 BHK  Coomee       1056.0   2.0      1.0   39.07   2
# ...

# %%
df[~df['total_sqft'].apply(is_float)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price, bhk]
# Index: []

# %%
df['price_per_sqft']=df['price']/df['total_sqft']

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price bhk  \
# 0          2 BHK  Coomee       1056.0   2.0      1.0   39.07   2
# ...

# %%
df.location = df.location.str.strip()

# %%
less_locs=df['location'].value_counts()[df['location'].value_counts()<=10]

# %%
df.location=df.location.apply(lambda x : 'other' if x in less_locs else x)

# %%
df.location.value_counts()
# Out:
# location
# other                 2885
# Whitefield             541
# Sarjapur  Road         399
# Electronic City        304
# Kanakpura Road         273
#                       ...
# Nehru Nagar             11
# Banjara Layout          11
# LB Shastri Nagar        11
# Pattandur Agrahara      11
# Narayanapura            11
# Name: count, Length: 242, dtype: int64

# %%
df.bhk=df.bhk.astype(float)

# %%
df.dtypes
# Out:
# area_type          object
# availability       object
# location           object
# size               object
# society            object
# total_sqft        float64
# bath              float64
# balcony           float64
# price             float64
# bhk               float64
# price_per_sqft    float64
# dtype: object

# %%
df[df.total_sqft/df.bhk<300]
# Out:
#         area_type   availability             location       size society  \
# 9      Plot  Area  Ready To Move                other  6 Bedroom     NaN
# 45     Plot  Area  Ready To Move           HSR Layout  8 Bedroom     NaN
# 58     Plot  Area  Ready To Move        Murugeshpalya  6 Bedroom     NaN
# 68     Plot  Area  Ready To Move  Devarachikkanahalli  8 Bedroom     NaN
# 70     Plot  Area  Ready To Move                other  3 Bedroom     NaN
# ...           ...            ...                  ...        ...     ...
# 13277  Plot  Area  Ready To Move                other  7 Bedroom     NaN
# 13279  Plot  Area  Ready To Move                other  6 Bedroom     NaN
# 13281  Plot  Area  Ready To Move      Margondanahalli  5 Bedroom     NaN
# 13303  Plot  Area  Ready To Move       Vidyaranyapura  5 Bedroom     NaN
# 13311  Plot  Area  Ready To Move     Ramamurthy Nagar  7 Bedroom     NaN
#
#        total_sqft  bath  balcony  price  bhk  price_per_sqft
# ...

# %%
df=df[(df.total_sqft/df.bhk)>300]

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move                     other
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK  Coomee       1056.0   2.0      1.0   39.07  2.0
# ...

# %%
df.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  12332.000000  12275.000000  11848.000000  12332.000000  12332.000000
# mean    1600.262912      2.545499      1.590142    110.838610      2.634123
# std     1268.883065      1.067516      0.807543    152.817077      0.964757
# min      340.000000      1.000000      0.000000      9.000000      1.000000
# 25%     1115.000000      2.000000      1.000000     49.000000      2.000000
# 50%     1305.000000      2.000000      2.000000     69.500000      3.000000
# 75%     1705.250000      3.000000      2.000000    115.000000      3.000000
# max    52272.000000     16.000000      3.000000   3600.000000     16.000000
#
#        price_per_sqft
# count    12332.000000
# mean         0.062112
# std          0.040461
# min          0.002678
# 25%          0.042000
# 50%          0.052682
# 75%          0.068278
# max          1.764706

# %%
df[df['price_per_sqft']<(0.002678-(3*0.040461))]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price, bhk, price_per_sqft]
# Index: []

# %%
df[df['price_per_sqft']>(0.002678+(3*0.040461))]
# Out:
#                   area_type   availability            location       size  \
# 7      Super built-up  Area  Ready To Move        Rajaji Nagar      4 BHK
# 22               Plot  Area  Ready To Move         Thanisandra  4 Bedroom
# 48               Plot  Area  Ready To Move            KR Puram  2 Bedroom
# 107          Built-up  Area  Ready To Move        Rajaji Nagar      3 BHK
# 159              Plot  Area  Ready To Move  Mahalakshmi Layout  4 Bedroom
# ...                     ...            ...                 ...        ...
# 13200            Plot  Area  Ready To Move               other  6 Bedroom
# 13233        Built-up  Area  Ready To Move               other      3 BHK
# 13261            Plot  Area  Ready To Move               other  3 Bedroom
# 13262        Built-up  Area  Ready To Move               other      2 BHK
# 13305          Carpet  Area  Ready To Move            Hulimavu      1 BHK
#
#        society  total_sqft  bath  balcony   price  bhk  price_per_sqft
# ...

# %%
df=df[df['price_per_sqft']<(0.002678+(3*0.040461))]

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move                     other
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK  Coomee       1056.0   2.0      1.0   39.07  2.0
# ...

# %%
df = df[df.bath<df.bhk+2]

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move                     other
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK  Coomee       1056.0   2.0      1.0   39.07  2.0
# ...

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df = remove_bhk_outliers(df)
# df8 = df7.copy()
df.shape
# Out:
# (8203, 11)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'total_sqft'}>,
#         <Axes: title={'center': 'bath'}>],
#        [<Axes: title={'center': 'balcony'}>,
#         <Axes: title={'center': 'price'}>],
#        [<Axes: title={'center': 'bhk'}>,
#         <Axes: title={'center': 'price_per_sqft'}>]], dtype=object)

# %%
df
# Out:
#                   area_type   availability                  location   size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 6      Super built-up  Area         18-May          Old Airport Road  4 BHK
# ...                     ...            ...                       ...    ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  3 BHK
# 13316  Super built-up  Area  Ready To Move                     other  4 BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4 BHK
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  1 BHK
#
# ...

# %%
df.select_dtypes("number").corr()
# Out:
#                 total_sqft      bath   balcony     price       bhk  \
# total_sqft        1.000000  0.668213  0.247366  0.850226  0.651687
# bath              0.668213  1.000000  0.298741  0.642200  0.902942
# balcony           0.247366  0.298741  1.000000  0.229845  0.289941
# price             0.850226  0.642200  0.229845  1.000000  0.611839
# bhk               0.651687  0.902942  0.289941  0.611839  1.000000
# price_per_sqft    0.337028  0.364614  0.105340  0.675676  0.345676
#
#                 price_per_sqft
# total_sqft            0.337028
# bath                  0.364614
# balcony               0.105340
# price                 0.675676
# bhk                   0.345676
# price_per_sqft        1.000000

# %%
dummies = pd.get_dummies(df.location)

# %%
dummies
# Out:
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                    False               False                      False
# 2                    False               False                      False
# 3                    False               False                      False
# 4                    False               False                      False
# 6                    False               False                      False
# ...                    ...                 ...                        ...
# 13314                False               False                      False
# 13316                False               False                      False
# 13317                False               False                      False
# 13318                False               False                      False
# 13319                False               False                      False
#
#        2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# ...

# %%
df2 = pd.concat([df,dummies.drop('other',axis='columns')],axis='columns')

# %%
df2
# Out:
#                   area_type   availability                  location   size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 6      Super built-up  Area         18-May          Old Airport Road  4 BHK
# ...                     ...            ...                       ...    ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  3 BHK
# 13316  Super built-up  Area  Ready To Move                     other  4 BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4 BHK
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  1 BHK
#
# ...

# %%
df2=df2.drop(['area_type','society','balcony','availability','size'],axis='columns')

# %%
df2.drop(columns='location',inplace=True)

# %%
x = df2.drop(['price'],axis='columns')

# %%
y = df2.price.values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x_train,y_train)
lr_clf.score(x_test,y_test)
# Out:
# 0.9103470041938093

# %%
df2
# Out:
#        total_sqft  bath   price  bhk  price_per_sqft  1st Block Jayanagar  \
# 0          1056.0   2.0   39.07  2.0        0.036998                False
# 2          1440.0   2.0   62.00  3.0        0.043056                False
# 3          1521.0   3.0   95.00  3.0        0.062459                False
# 4          1200.0   2.0   51.00  2.0        0.042500                False
# 6          2732.0   4.0  204.00  4.0        0.074671                False
# ...           ...   ...     ...  ...             ...                  ...
# 13314      1715.0   3.0  112.00  3.0        0.065306                False
# 13316      3600.0   5.0  400.00  4.0        0.111111                False
# 13317      1141.0   2.0   60.00  2.0        0.052585                False
# 13318      4689.0   4.0  488.00  4.0        0.104073                False
# 13319       550.0   1.0   17.00  1.0        0.030909                False
#
#        1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# ...

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X, y):
    algos = {
        'linear_regression': {
            'model': LinearRegression(),
            'params': {
                'fit_intercept': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1, 2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion': ['squared_error', 'friedman_mse'],
                'splitter': ['best', 'random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X, y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
find_best_model_using_gridsearchcv(x,y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.934484
# 1              lasso    0.799016
# 2      decision_tree    0.927353
#
#                                          best_params
# 0                            {'fit_intercept': True}
# 1                {'alpha': 2, 'selection': 'random'}
# 2  {'criterion': 'squared_error', 'splitter': 'be...
