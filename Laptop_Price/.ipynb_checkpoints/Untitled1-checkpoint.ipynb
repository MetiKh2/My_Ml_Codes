# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('laptop_data.csv')
df=data.copy()
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df['Weight']=df['Weight'].str[:-2]
df['Ram']=df['Ram'].str[:-2]
df.Weight=df.Weight.astype(float)
df.Ram=df.Ram.astype(float)

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                 float64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2=df.copy()
df2['Company']=le.fit_transform(df2['Company'])
df2['TypeName']=le.fit_transform(df2['TypeName'])
df2['ScreenResolution']=le.fit_transform(df2['ScreenResolution'])
df2['Cpu']=le.fit_transform(df2['Cpu'])
df2['Memory']=le.fit_transform(df2['Memory'])
df2['Gpu']=le.fit_transform(df2['Gpu'])
df2['OpSys']=le.fit_transform(df2['OpSys'])

# %%
df2
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu   Ram  Memory  Gpu  \
# 0           1         4    13.3                23   65   8.0       4   58
# 1           1         4    13.3                 1   63   8.0       2   51
# 2           7         3    15.6                 8   74   8.0      16   53
# 3           1         4    15.4                25   85  16.0      29    9
# 4           1         4    13.3                23   67   8.0      16   59
# ...       ...       ...     ...               ...  ...   ...     ...  ...
# 1298       10         0    14.0                13   89   4.0       4   47
# 1299       10         0    13.3                19   89  16.0      29   47
# 1300       10         3    14.0                 0   34   2.0      35   40
# 1301        7         3    15.6                 0   89   6.0      10   21
# 1302        2         3    15.6                 0   34   4.0      26   40
#
#       OpSys  Weight        Price
# 0         8    1.37   71378.6832
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

def eval_model(ytest,ypred):
    mae = mean_absolute_error(ytest,ypred)
    mse = mean_squared_error(ytest,ypred)
    rmse = mean_squared_error(ytest,ypred,squared=False)
    r2s = r2_score(ytest,ypred)
    return {'MAE':mae,'MSE':mse,'RMSE':rmse}

def model_res(model,x_train,x_test,y_train,y_test,ypred,mname):
    train_r2 = model.score(x_train,y_train)
    test_r2 = model.score(x_test,y_test)
    w = eval_model(y_test,ypred)
    res_metrics = {'Train_R2':train_r2,'Test_R2':test_r2,'Test_MSE':w['MSE'],
                    'Test_RMSE':w['RMSE'],'Test_MAE':w['MAE']}
    res = pd.DataFrame(res_metrics, index=[mname]) 
    return res, res_metrics

# %%
x = df2.drop('Price',axis=1)
# y = df2['Price']  
y = np.log(df2['Price'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=8)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_df,lr_res = model_res(lr,x_train,x_test,y_train,y_test,lr.predict(x_test),'LinReg')
lr_df
# Out:
#         Train_R2   Test_R2  Test_MSE  Test_RMSE  Test_MAE
# LinReg  0.694155  0.691318  0.120707   0.347429  0.280074

# %%
df3=df.copy()
df3
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df3 = pd.get_dummies(df3,columns=df3.dtypes[df3.dtypes=='object'].index,drop_first=True)

# %%
df3
# Out:
#       Inches   Ram  Weight        Price  Company_Apple  Company_Asus  \
# 0       13.3   8.0    1.37   71378.6832           True         False
# 1       13.3   8.0    1.34   47895.5232           True         False
# 2       15.6   8.0    1.86   30636.0000          False         False
# 3       15.4  16.0    1.83  135195.3360           True         False
# 4       13.3   8.0    1.37   96095.8080           True         False
# ...      ...   ...     ...          ...            ...           ...
# 1298    14.0   4.0    1.80   33992.6400          False         False
# 1299    13.3  16.0    1.30   79866.7200          False         False
# 1300    14.0   2.0    1.50   12201.1200          False         False
# 1301    15.6   6.0    2.19   40705.9200          False         False
# 1302    15.6   4.0    2.20   19660.3200          False          True
#
#       Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  ...  \
# ...

# %%
x = df3.drop('Price',axis=1)
y = df3['Price'].values.reshape(-1,1)  

# x = df2.drop('Price',axis=1)
# y = df2['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=8)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# -1.2470007178350911e+19

# %%
lr_df,lr_res = model_res(lr,x_train,x_test,y_train,y_test,lr.predict(x_test),'LinReg')
lr_df
# Out:
#         Train_R2       Test_R2      Test_MSE     Test_RMSE      Test_MAE
# LinReg  0.927932 -1.247001e+19  1.704443e+28  1.305543e+14  1.485957e+13

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
new_df=df3.copy()
new_df['pred']=lr.predict(x)
plt.figure(figsize=(90,19))
# plt.xticks(range(0,500000,1000))
# plt.yticks(range(0,20000,500))
plt.plot(new_df.sort_values(by="Weight")["Weight"],new_df.sort_values(by="Weight")["pred"],color="Blue")
plt.scatter(new_df.sort_values(by="Weight")["Weight"],new_df.sort_values(by="Weight")["Price"],color="red")

# %%
new_df=df3.copy()
new_df['pred']=lr.predict(x)
plt.figure(figsize=(90,19))
# plt.xticks(range(0,500000,1000))
# plt.yticks(range(0,20000,500))
plt.plot(new_df.sort_values(by="Inches")["Inches"],new_df.sort_values(by="Inches")["pred"],color="Blue")
plt.scatter(new_df.sort_values(by="Inches")["Inches"],new_df.sort_values(by="Inches")["Price"],color="red")

# %%
new_df.sort_values(by='pred',ascending=False)
# Out:
#       Inches   Ram  Weight        Price  Company_Apple  Company_Asus  \
# 1066    17.3  64.0    3.58  211788.0000          False          True
# 1081    17.3  32.0    4.60  172627.2000          False         False
# 610     15.6  32.0    2.50  261018.7200          False         False
# 841     17.3  32.0    4.42  163723.5792          False         False
# 491     13.3  32.0    1.05  149130.7200          False         False
# ...      ...   ...     ...          ...            ...           ...
# 907     15.6   4.0    2.20   19127.5200          False         False
# 1215    11.6   2.0    1.30    9270.7200          False         False
# 745     14.0   2.0    1.68   17582.4000          False         False
# 1102    15.6   4.0    2.20   11135.5200          False         False
# 290     15.6   2.0    2.19   10602.7200          False         False
#
#       Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  ...  \
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.671796321664742

# %%
plt.scatter(new_df["pred"],new_df["Price"],color="Blue")

# %%
new_df
# Out:
#       Inches   Ram  Weight        Price  Company_Apple  Company_Asus  \
# 0       13.3   8.0    1.37   71378.6832           True         False
# 1       13.3   8.0    1.34   47895.5232           True         False
# 2       15.6   8.0    1.86   30636.0000          False         False
# 3       15.4  16.0    1.83  135195.3360           True         False
# 4       13.3   8.0    1.37   96095.8080           True         False
# ...      ...   ...     ...          ...            ...           ...
# 1298    14.0   4.0    1.80   33992.6400          False         False
# 1299    13.3  16.0    1.30   79866.7200          False         False
# 1300    14.0   2.0    1.50   12201.1200          False         False
# 1301    15.6   6.0    2.19   40705.9200          False         False
# 1302    15.6   4.0    2.20   19660.3200          False          True
#
#       Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  ...  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

# %%
dt = DecisionTreeRegressor(max_depth=8,min_samples_split=10,min_samples_leaf=10)
dt.fit(x_train,y_train)
ypred_dt = dt.predict(x_test)
dt_df,dt_res = model_res(dt,x_train,x_test,y_train,y_test,ypred_dt,'DTree_Reg')
dt_df
# Out:
#            Train_R2  Test_R2      Test_MSE     Test_RMSE     Test_MAE
# DTree_Reg  0.806621  0.68362  4.812854e+08  21938.218348  13993.96436

# %%
rf = RandomForestRegressor(n_estimators=300,max_depth=12,min_samples_split=2)
rf.fit(x_train,y_train)
ypred_rf =  rf.predict(x_test)
rf_df,rf_res = model_res(rf,x_train,x_test,y_train,y_test,ypred_rf,'RF_Reg')
rf_df
# Out:
#         Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# RF_Reg  0.956319  0.804498  2.974029e+08  17245.373661  11015.483393

# %%
rf2 = RandomForestRegressor(n_estimators=300,max_depth=9,min_samples_split=4)
rf2.fit(x_train,y_train)
ypred_rf2 =  rf2.predict(x_test)
rf_df1,rf_re1s = model_res(rf2,x_train,x_test,y_train,y_test,ypred_rf2,'RF_Reg1')
rf_df1
# Out:
#          Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# RF_Reg1  0.922882  0.789531  3.201699e+08  17893.292108  11800.242505

# %%
res_df = pd.DataFrame({'Actual_y_test':y_test,'Pred':ypred_rf2})
res_df.sample(20)
# Out:
#       Actual_y_test          Pred
# 1041     11231.4240  15722.241154
# 862      68464.8000  64138.000813
# 10       20986.9920  29973.660081
# 974     109218.6720  91296.414387
# 506      65214.7200  53184.873356
# 9        41025.6000  58246.095924
# 27       42624.0000  48779.353702
# 993      71874.7200  53318.220076
# 540      74538.7200  77203.405246
# 790      71341.9200  63479.880926
# 299      78215.0400  96221.894321
# 601      35616.6144  31944.264404
# 957      41292.0000  34769.594663
# 140      34898.4000  32681.161337
# 390      55357.9200  59658.410269
# 751     101232.0000  63551.824299
# 418      28768.5360  34243.687310
# 762      83063.5200  75137.543242
# 276      58554.7200  49325.965368
# 926      87912.0000  77970.622660

# %%
from sklearn.neighbors import KNeighborsRegressor
for i in range(2,20):
    knn = KNeighborsRegressor(n_neighbors=i)
    knn.fit(x_train,y_train)
    ypred_knn =  knn.predict(x_test)
    knn_df1,knn_re1s = model_res(knn,x_train,x_test,y_train,y_test,ypred_knn,'KNN')
    print(knn_df1)
# Out:
#      Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# KNN  0.924167  0.780801  2.996080e+08  17309.187695  10647.838844
#      Train_R2   Test_R2      Test_MSE     Test_RMSE     Test_MAE
# KNN  0.887796  0.797589  2.766619e+08  16633.155284  10043.83895
#      Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# KNN  0.854537  0.773347  3.097970e+08  17601.051608  10732.967128
#      Train_R2   Test_R2      Test_MSE     Test_RMSE     Test_MAE
# KNN   0.84221  0.765611  3.203715e+08  17898.923289  10865.25769
#      Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# KNN  0.829116  0.771502  3.123182e+08  17672.527335  11051.317988
#      Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# KNN  0.817062  0.766112  3.196859e+08  17879.762965  11427.301546
#      Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# KNN  0.804203  0.762391  3.247717e+08  18021.423794  11590.880952
# ...

# %%
knn = KNeighborsRegressor(n_neighbors=2)
knn.fit(x_train,y_train)
ypred_knn =  knn.predict(x_test)
knn_df1,knn_re1s = model_res(knn,x_train,x_test,y_train,y_test,ypred_knn,'KNN')
knn_df1
# Out:
#      Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# KNN  0.924167  0.780801  2.996080e+08  17309.187695  10647.838844
