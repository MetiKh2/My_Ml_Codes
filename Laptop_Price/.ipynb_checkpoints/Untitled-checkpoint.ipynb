# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('laptop_data.csv')
df=data.copy()
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_157cd thead>tr>th {
#   text-align: left;
# }
# #T_157cd_row0_col0, #T_157cd_row1_col0, #T_157cd_row2_col0, #T_157cd_row3_col0, #T_157cd_row4_col0, #T_157cd_row5_col0, #T_157cd_row6_col0, #T_157cd_row7_col0, #T_157cd_row8_col0, #T_157cd_row9_col0, #T_157cd_row10_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_157cd_row0_col1, #T_157cd_row1_col1, #T_157cd_row2_col1, #T_157cd_row3_col1, #T_157cd_row4_col1, #T_157cd_row5_col1, #T_157cd_row6_col1, #T_157cd_row7_col1, #T_157cd_row8_col1, #T_157cd_row9_col1, #T_157cd_row10_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %%
print(df.Company.value_counts())
df.Company.value_counts().plot(kind='bar')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64
# <Axes: xlabel='Company'>

# %%
print(df.TypeName.value_counts())
df.TypeName.value_counts().plot(kind='bar')
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64
# <Axes: xlabel='TypeName'>

# %%
df.Inches.hist(bins=20)
# Out:
# <Axes: >

# %%
print(df.ScreenResolution.nunique())
print(df.ScreenResolution.value_counts())
df.ScreenResolution.value_counts().plot(kind='bar')
# Out:
# 40
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
print(df.Cpu.nunique())
print(df.Cpu.value_counts())
df.Cpu.value_counts().plot(kind='bar')
# Out:
# 118
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64
# <Axes: xlabel='Cpu'>

# %%
print(df.Ram.nunique())
print(df.Ram.value_counts())
df.Ram.value_counts().plot(kind='bar')
# Out:
# 9
# Ram
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: count, dtype: int64
# <Axes: xlabel='Ram'>

# %%
print(df.Memory.nunique())
print(df.Memory.value_counts())
df.Memory.value_counts().plot(kind='bar')
# Out:
# 39
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
print(df.Gpu.nunique())
print(df.Gpu.value_counts())
df.Gpu.value_counts().plot(kind='bar')
# Out:
# 110
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64
# <Axes: xlabel='Gpu'>

# %%
print(df.OpSys.nunique())
print(df.OpSys.value_counts())
df.OpSys.value_counts().plot(kind='bar')
# Out:
# 9
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64
# <Axes: xlabel='OpSys'>

# %%
print(df.Weight.nunique())
print(df.Weight.value_counts())
df.Weight.value_counts().plot(kind='bar')
# Out:
# 179
# Weight
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: count, Length: 179, dtype: int64
# <Axes: xlabel='Weight'>

# %%
df.Price.hist(bins=20)
# Out:
# <Axes: >

# %%
df.sort_values(by="Price",ascending=False)
# Out:
#      Company     TypeName  Inches                     ScreenResolution  \
# 196    Razer       Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
# 830    Razer       Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
# 610   Lenovo     Notebook    15.6      IPS Panel 4K Ultra HD 3840x2160
# 749       HP  Workstation    17.3          IPS Panel Full HD 1920x1080
# 1066    Asus       Gaming    17.3          IPS Panel Full HD 1920x1080
# ...      ...          ...     ...                                  ...
# 290     Acer     Notebook    15.6                             1366x768
# 31      Asus     Notebook    14.0                             1366x768
# 1120    Vero     Notebook    13.3                    Full HD 1920x1080
# 20      Asus      Netbook    11.6                             1366x768
# 1215    Acer      Netbook    11.6                             1366x768
#
#                                        Cpu   Ram              Memory  \
# ...

# %%
df['Weight']=df['Weight'].str[:-2]
df['Ram']=df['Ram'].str[:-2]

# %%
df.Weight=df.Weight.astype(float)
df.Ram=df.Ram.astype(float)

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                 float64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
df.describe()
# Out:
#             Inches          Ram       Weight          Price
# count  1303.000000  1303.000000  1303.000000    1303.000000
# mean     15.017191     8.382195     2.038734   59870.042910
# std       1.426304     5.084665     0.665475   37243.201786
# min      10.100000     2.000000     0.690000    9270.720000
# 25%      14.000000     4.000000     1.500000   31914.720000
# 50%      15.600000     8.000000     2.040000   52054.560000
# 75%      15.600000     8.000000     2.300000   79274.246400
# max      18.400000    64.000000     4.700000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   float64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 112.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2=df.copy()
df2['Company']=le.fit_transform(df2['Company'])
df2['TypeName']=le.fit_transform(df2['TypeName'])
df2['ScreenResolution']=le.fit_transform(df2['ScreenResolution'])
df2['Cpu']=le.fit_transform(df2['Cpu'])
df2['Memory']=le.fit_transform(df2['Memory'])
df2['Gpu']=le.fit_transform(df2['Gpu'])
df2['OpSys']=le.fit_transform(df2['OpSys'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df2.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation",fontsize=20)
plt.show()

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TouchScreen'] = df['ScreenResolution'].apply(lambda x :1 if 'Touchscreen' in x else 0)

# %%
df2['TouchScreen']=df['TouchScreen']

# %%
df2
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu   Ram  Memory  Gpu  \
# 0           1         4    13.3                23   65   8.0       4   58
# 1           1         4    13.3                 1   63   8.0       2   51
# 2           7         3    15.6                 8   74   8.0      16   53
# 3           1         4    15.4                25   85  16.0      29    9
# 4           1         4    13.3                23   67   8.0      16   59
# ...       ...       ...     ...               ...  ...   ...     ...  ...
# 1298       10         0    14.0                13   89   4.0       4   47
# 1299       10         0    13.3                19   89  16.0      29   47
# 1300       10         3    14.0                 0   34   2.0      35   40
# 1301        7         3    15.6                 0   89   6.0      10   21
# 1302        2         3    15.6                 0   34   4.0      26   40
#
#       OpSys  Weight        Price  TouchScreen
# ...

# %%
df['TouchScreen'].value_counts()
# Out:
# TouchScreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x :1 if 'IPS' in x else 0)
df2['Ips']=df['Ips']

# %% [markdown]
# ##

# %%
df2
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu   Ram  Memory  Gpu  \
# 0           1         4    13.3                23   65   8.0       4   58
# 1           1         4    13.3                 1   63   8.0       2   51
# 2           7         3    15.6                 8   74   8.0      16   53
# 3           1         4    15.4                25   85  16.0      29    9
# 4           1         4    13.3                23   67   8.0      16   59
# ...       ...       ...     ...               ...  ...   ...     ...  ...
# 1298       10         0    14.0                13   89   4.0       4   47
# 1299       10         0    13.3                19   89  16.0      29   47
# 1300       10         3    14.0                 0   34   2.0      35   40
# 1301        7         3    15.6                 0   89   6.0      10   21
# 1302        2         3    15.6                 0   34   4.0      26   40
#
#       OpSys  Weight        Price  TouchScreen  Ips
# ...

# %%
sns.barplot(x=df2['Ips'],y=df2['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ips'].value_counts()
# Out:
# Ips
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
new=df['ScreenResolution'].str.split('x')

# %%
new
# Out:
# 0               [IPS Panel Retina Display 2560, 1600]
# 1                                         [1440, 900]
# 2                                [Full HD 1920, 1080]
# 3               [IPS Panel Retina Display 2880, 1800]
# 4               [IPS Panel Retina Display 2560, 1600]
#                             ...
# 1298     [IPS Panel Full HD / Touchscreen 1920, 1080]
# 1299    [IPS Panel Quad HD+ / Touchscreen 3200, 1800]
# 1300                                      [1366, 768]
# 1301                                      [1366, 768]
# 1302                                      [1366, 768]
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df['Y_res']=0
df['X_res']=0
for i in range(0,len(new)):
    df['Y_res'][i]=int(new[i][1])
    df['X_res'][i]=int(new[i][0][-4:])

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.Cpu.value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df.Cpu.nunique()
# Out:
# 118

# %%
def fetch_processor(text):
    if  'Intel Core i7' in text or  'Intel Core i5' in text or 'Intel Core i3' in text:
        return text[0:13]
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu'].apply(fetch_processor)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x=df['Cpu brand'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.Memory.value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].str.split(' ',expand=True)[0]
df["first"] = df["first"].astype(int)
df["second"] = df["second"].str.split(' ',expand=True)[0]
df["second"] = df['second'].apply(lambda x : 0 if x=='' else x)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'TouchScreen', 'Ips',
#        'Y_res', 'X_res', 'Cpu brand', 'HDD', 'SSD', 'Hybrid', 'Flash_Storage'],
#       dtype='object')

# %%
df.sort_values(by='Hybrid')
# Out:
#       Company   TypeName  Inches                    ScreenResolution  \
# 0       Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 866   Toshiba  Ultrabook    13.3                            1366x768
# 865        HP   Notebook    15.6                   Full HD 1920x1080
# 864      Dell  Ultrabook    13.3    Quad HD+ / Touchscreen 3200x1800
# 863    Lenovo     Gaming    15.6         IPS Panel Full HD 1920x1080
# ...       ...        ...     ...                                 ...
# 1010     Dell     Gaming    15.6                   Full HD 1920x1080
# 1135   Lenovo   Notebook    15.6                   Full HD 1920x1080
# 1176   Lenovo   Notebook    15.6                   Full HD 1920x1080
# 1266       HP   Notebook    15.6                   Full HD 1920x1080
# 1258   Lenovo   Notebook    15.6                   Full HD 1920x1080
#
#                               Cpu   Ram       Memory  \
# 0            Intel Core i5 2.3GHz   8.0      128 SSD
# ...

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df3=df.copy()

# %%
df3
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df3.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                 float64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# TouchScreen           int64
# Ips                   int64
# Y_res                 int64
# X_res                 int64
# Cpu brand            object
# HDD                   int64
# SSD                   int64
# Hybrid                int64
# Flash_Storage         int64
# Gpu brand            object
# os                   object
# dtype: object

# %%
df2=df.copy()
df2
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2=df.copy()
df2['Company']=le.fit_transform(df2['Company'])
df2['TypeName']=le.fit_transform(df2['TypeName'])
df2['ScreenResolution']=le.fit_transform(df2['ScreenResolution'])
df2['Cpu']=le.fit_transform(df2['Cpu'])
df2['Memory']=le.fit_transform(df2['Memory'])
df2['Gpu']=le.fit_transform(df2['Gpu'])
df2['OpSys']=le.fit_transform(df2['OpSys'])
df2['Cpu brand']=le.fit_transform(df2['Cpu brand'])
df2['Gpu brand']=le.fit_transform(df2['Gpu brand'])
df2['os']=le.fit_transform(df2['os'])

# %%
df2.dtypes
# Out:
# Company               int32
# TypeName              int32
# Inches              float64
# ScreenResolution      int32
# Cpu                   int32
# Ram                 float64
# Memory                int32
# Gpu                   int32
# OpSys                 int32
# Weight              float64
# Price               float64
# TouchScreen           int64
# Ips                   int64
# Y_res                 int64
# X_res                 int64
# Cpu brand             int32
# HDD                   int64
# SSD                   int64
# Hybrid                int64
# Flash_Storage         int64
# Gpu brand             int32
# os                    int32
# dtype: object

# %%
df3.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                 float64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# TouchScreen           int64
# Ips                   int64
# Y_res                 int64
# X_res                 int64
# Cpu brand            object
# HDD                   int64
# SSD                   int64
# Hybrid                int64
# Flash_Storage         int64
# Gpu brand            object
# os                   object
# dtype: object

# %%
df3.drop(columns=['ScreenResolution','Cpu','Memory','Gpu','OpSys'],inplace=True
    )

# %%
df_dum = pd.get_dummies(df3,columns=df3.dtypes[df.dtypes=='object'].index,drop_first=True)
print(df_dum.shape)
print(df_dum.columns)
# Out:
# (1302, 43)
# Index(['Inches', 'Ram', 'Weight', 'Price', 'TouchScreen', 'Ips', 'Y_res',
#        'X_res', 'HDD', 'SSD', 'Hybrid', 'Flash_Storage', 'Company_Apple',
#        'Company_Asus', 'Company_Chuwi', 'Company_Dell', 'Company_Fujitsu',
#        'Company_Google', 'Company_HP', 'Company_Huawei', 'Company_LG',
#        'Company_Lenovo', 'Company_MSI', 'Company_Mediacom',
#        'Company_Microsoft', 'Company_Razer', 'Company_Samsung',
#        'Company_Toshiba', 'Company_Vero', 'Company_Xiaomi', 'TypeName_Gaming',
#        'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook',
#        'TypeName_Workstation', 'Cpu brand_Intel Core i3',
#        'Cpu brand_Intel Core i5', 'Cpu brand_Intel Core i7',
#        'Cpu brand_Other Intel Processor', 'Gpu brand_Intel',
#        'Gpu brand_Nvidia', 'os_Others/No OS/Linux', 'os_Windows'],
#       dtype='object')

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
def eval_model(ytest,ypred):
    mae = mean_absolute_error(ytest,ypred)
    mse = mean_squared_error(ytest,ypred)
    rmse = mean_squared_error(ytest,ypred,squared=False)
    r2s = r2_score(ytest,ypred)
    return {'MAE':mae,'MSE':mse,'RMSE':rmse}

def model_res(model,x_train,x_test,y_train,y_test,ypred,mname):
    train_r2 = model.score(x_train,y_train)
    test_r2 = model.score(x_test,y_test)
    w = eval_model(y_test,ypred)
    res_metrics = {'Train_R2':train_r2,'Test_R2':test_r2,'Test_MSE':w['MSE'],
                    'Test_RMSE':w['RMSE'],'Test_MAE':w['MAE']}
    res = pd.DataFrame(res_metrics, index=[mname]) 
    return res, res_metrics

# %%
x1 = df2.drop('Price',axis=1)
y1 = df2['Price']

# %%
x2 = df_dum.drop('Price',axis=1)
y2 = df_dum['Price']

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(x1,y1,test_size=0.25,random_state=8)
x_train2,x_test2,y_train2,y_test2 = train_test_split(x2,y2,test_size=0.25,random_state=8)

# %%
from sklearn.linear_model import LinearRegression
lr1 = LinearRegression()
lr2 = LinearRegression()
lr1.fit(x_train1,y_train1)
lr2.fit(x_train2,y_train2)
# Out:
# LinearRegression()

# %%
ypred_lr1 =  lr1.predict(x_test1)
ypred_lr2 =  lr2.predict(x_test2)

# %%
lr1_df,lr_res = model_res(lr1,x_train1,x_test1,y_train1,y_test1,ypred_lr1,'LinReg')
lr1_df
# Out:
#         Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# LinReg   0.73994  0.717152  3.716077e+08  19277.129235  14390.883906

# %%
lr2_df,lr_res = model_res(lr2,x_train2,x_test2,y_train2,y_test2,ypred_lr1,'LinReg')
lr2_df
# Out:
#         Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# LinReg  0.782926  0.767387  3.716077e+08  19277.129235  14390.883906

# %%
x2
# Out:
#       Inches   Ram  Weight  TouchScreen  Ips  Y_res  X_res   HDD  SSD  Hybrid  \
# 0       13.3   8.0    1.37            0    1   1600   2560     0  128       0
# 1       13.3   8.0    1.34            0    0    900   1440     0    0       0
# 2       15.6   8.0    1.86            0    0   1080   1920     0  256       0
# 3       15.4  16.0    1.83            0    1   1800   2880     0  512       0
# 4       13.3   8.0    1.37            0    1   1600   2560     0  256       0
# ...      ...   ...     ...          ...  ...    ...    ...   ...  ...     ...
# 1298    14.0   4.0    1.80            1    1   1080   1920     0  128       0
# 1299    13.3  16.0    1.30            1    1   1800   3200     0  512       0
# 1300    14.0   2.0    1.50            0    0    768   1366     0    0       0
# 1301    15.6   6.0    2.19            0    0    768   1366  1000    0       0
# 1302    15.6   4.0    2.20            0    0    768   1366   500    0       0
#
# ...

# %%
x1
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu   Ram  Memory  Gpu  \
# 0           1         4    13.3                23   65   8.0       7   57
# 1           1         4    13.3                 1   63   8.0       5   50
# 2           7         3    15.6                 8   74   8.0      16   52
# 3           1         4    15.4                25   85  16.0      28    9
# 4           1         4    13.3                23   67   8.0      16   58
# ...       ...       ...     ...               ...  ...   ...     ...  ...
# 1298       10         0    14.0                13   89   4.0       7   46
# 1299       10         0    13.3                19   89  16.0      28   46
# 1300       10         3    14.0                 0   34   2.0      34   39
# 1301        7         3    15.6                 0   89   6.0       0   21
# 1302        2         3    15.6                 0   34   4.0      25   39
#
#       OpSys  Weight  ...  Ips  Y_res  X_res  Cpu brand   HDD  SSD  Hybrid  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

# %%
dt1 = DecisionTreeRegressor(max_depth=8,min_samples_split=10,min_samples_leaf=10)
dt1.fit(x_train1,y_train1)
dt2 = DecisionTreeRegressor(max_depth=8,min_samples_split=10,min_samples_leaf=10)
dt2.fit(x_train2,y_train2)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=10)

# %%
ypred_dt1 = dt1.predict(x_test1)
ypred_dt2 = dt2.predict(x_test2)

# %%
dt_df1,dt_res1 = model_res(dt1,x_train1,x_test1,y_train1,y_test1,ypred_dt1,'DTree_Reg')
dt_df1
# Out:
#            Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# DTree_Reg   0.81351  0.769352  3.030270e+08  17407.671804  11440.795756

# %%
dt_df2,dt_res2 = model_res(dt2,x_train2,x_test2,y_train2,y_test2,ypred_dt2,'DTree_Reg')
dt_df2
# Out:
#            Train_R2   Test_R2      Test_MSE    Test_RMSE      Test_MAE
# DTree_Reg  0.802116  0.746422  3.331527e+08  18252.47032  11900.047849

# %%
rf1 = RandomForestRegressor(max_depth=8,min_samples_split=10,min_samples_leaf=10)
rf1.fit(x_train1,y_train1)
rf2 = RandomForestRegressor(max_depth=8,min_samples_split=10,min_samples_leaf=10)
rf2.fit(x_train2,y_train2)

ypred_rf1 = rf1.predict(x_test1)
ypred_rf2 = rf2.predict(x_test2)

# %%
rf_df1,rf_res1 = model_res(rf1,x_train1,x_test1,y_train1,y_test1,ypred_rf1,'DTree_Reg')
rf_df1
# Out:
#            Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# DTree_Reg  0.823225  0.792777  2.722510e+08  16500.031435  11034.517508

# %%
rf_df2,rf_res2 = model_res(rf2,x_train2,x_test2,y_train2,y_test2,ypred_rf2,'dd')
rf_df2
# Out:
#     Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# dd  0.806618  0.773597  2.974498e+08  17246.734327  11609.932825

# %%
ada1 = AdaBoostRegressor(n_estimators=200,random_state=8)
ada1.fit(x_train1,y_train1)
# Out:
# AdaBoostRegressor(n_estimators=200, random_state=8)

# %%
ada_pred1 = ada1.predict(x_test1)

# %%
ada_df1,ada_res1 = model_res(ada1,x_train1,x_test1,y_train1,y_test1,ada_pred1,'DTree_Reg')
ada_df1
# Out:
#            Train_R2   Test_R2      Test_MSE     Test_RMSE      Test_MAE
# DTree_Reg  0.640407  0.566929  5.689718e+08  23853.130161  21103.165609
