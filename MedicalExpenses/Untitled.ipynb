# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly 
import plotly.express as px

# %%
df = pd.read_csv('medical_expenses.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_83cf5 thead>tr>th {
#   text-align: left;
# }
# #T_83cf5_row0_col0, #T_83cf5_row1_col0, #T_83cf5_row2_col0, #T_83cf5_row3_col0, #T_83cf5_row4_col0, #T_83cf5_row5_col0, #T_83cf5_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_83cf5_row0_col1, #T_83cf5_row1_col1, #T_83cf5_row2_col1, #T_83cf5_row3_col1, #T_83cf5_row4_col1, #T_83cf5_row5_col1, #T_83cf5_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_83cf5_row0_col2, #T_83cf5_row1_col2, #T_83cf5_row2_col2, #T_83cf5_row3_col2, #T_83cf5_row4_col2, #T_83cf5_row5_col2, #T_83cf5_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# ...

# %%
sns.boxplot(data=df['children'])
plt.show()
sns.boxplot(data=df['bmi'])
plt.show()
sns.boxplot(data=df['charges'])
# Out:
# <Axes: ylabel='charges'>

# %%
df.plot.scatter(x='age',y='charges')
df.plot.scatter(x='bmi',y='charges')
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.sex=le.fit_transform(df.sex)
df.smoker=le.fit_transform(df.smoker)
df.region=le.fit_transform(df.region)

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation",fontsize=20)
plt.show()

# %%
sns.barplot(x='smoker',y='charges',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
sns.barplot(x='sex',y='charges',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
df.children.hist()
# Out:
# <Axes: >

# %%
df[df['smoker']==1].age.hist()
# Out:
# <Axes: >

# %%
df[df['smoker']==0].age.hist()
# Out:
# <Axes: >

# %%
sns.barplot(x='region',y='charges',data=df)
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.barplot(x='sex',y='children',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='children'>

# %%
sns.barplot(x='children',y='bmi',data=df)
# Out:
# <Axes: xlabel='children', ylabel='bmi'>

# %%
df.smoker.replace(to_replace=1,value=3,inplace=True)
df.smoker.replace(to_replace=0,value=2,inplace=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8028\3059970479.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.smoker.replace(to_replace=1,value=3,inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8028\3059970479.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['smoker_2']=df['smoker']**2

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges  smoker_2
# 0      19    0  27.900         0       3       3  16884.92400         9
# 1      18    1  33.770         1       2       2   1725.55230         4
# 2      28    1  33.000         3       2       2   4449.46200         4
# 3      33    1  22.705         0       2       1  21984.47061         4
# 4      32    1  28.880         0       2       1   3866.85520         4
# ...   ...  ...     ...       ...     ...     ...          ...       ...
# 1333   50    1  30.970         3       2       1  10600.54830         4
# 1334   18    0  31.920         0       2       0   2205.98080         4
# 1335   18    0  36.850         0       2       2   1629.83350         4
# 1336   21    0  25.800         0       2       3   2007.94500         4
# 1337   61    0  29.070         0       3       1  29141.36030         9
#
# [1338 rows x 8 columns]

# %%
df['smoker_bmi']=df['smoker']*df['bmi']
# df['smoker_age']=df['smoker']*df['age']
# df['children_bmi']=df['children']*df['age']
# df['bmi_2']=df['bmi']**2

# %%
x=df.drop(columns='charges')
y=df['charges'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
print(lr.score(x_test,y_test))
print(lr.score(x_train,y_train))
# Out:
# 0.8534722843163147
# 0.8361394906505403

# %%
lr_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(y_test, lr_pred)
rmse = np.sqrt(mean_squared_error(y_test, lr_pred))
print(mse)
print(rmse)
# Out:
# 22109734.017817676
# 4702.098894942308

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
print(rf.score(x_test,y_test))
print(rf.score(x_train,y_train))
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.8503764546411658
# 0.9760822030816321

# %%
rf_pred=rf.predict(x_test)

# %%
mse = mean_squared_error(y_test, rf_pred)
rmse = np.sqrt(mean_squared_error(y_test, rf_pred))
print(mse)
print(rmse)
# Out:
# 22576867.28583211
# 4751.512105196841

# %%
import xgboost as xg 
xgb_r = xg.XGBRegressor(objective ='reg:linear', 
                  n_estimators = 15) 
# Fitting the model 
xgb_r.fit(x_train, y_train) 
  
# Predict the model 
xgb_pred = xgb_r.predict(x_test) 
  
# RMSE Computation 
rmse = np.sqrt(mean_squared_error(y_test, xgb_pred  )) 
print("RMSE : % f" %(rmse)) 

print('r2',r2_score(y_test,xgb_pred  ))
# Out:
# RMSE :  4607.133554
# r2 0.8593311732804565
# C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:57:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
lr.score(x,y)
# Out:
# 0.8406079583721868

# %%
rf.score(x,y)
# Out:
# 0.9436748811021296

# %%
xgb_pred=xgb_r.predict(x)
r2_score(xgb_pred,y)
# Out:
# 0.9087158185830596

# %%
df['pred']=rf.predict(x)
df
# Out:
#       age  sex     bmi  children  smoker  region      charges  smoker_2  \
# 172    18    1  15.960         0       2       0   1694.79640         4
# 428    21    0  16.815         1       2       0   3167.45585         4
# 1226   38    1  16.815         2       2       0   6640.54485         4
# 412    26    0  17.195         2       3       0  14455.64405         9
# 1286   28    0  17.290         0       2       0   3732.62510         4
# ...   ...  ...     ...       ...     ...     ...          ...       ...
# 286    46    0  48.070         2       2       0   9432.92530         4
# 116    58    1  49.060         0       2       2  11381.32540         4
# 847    23    1  50.380         1       2       2   2438.05520         4
# 1047   22    1  52.580         1       3       2  44501.39820         9
# 1317   18    1  53.130         0       2       2   1163.46270         4
#
#       smoker_bmi          pred
# 172       31.920  17070.326997
# 428       33.630   5114.871149
# ...

# %%
df.sort_values(by='bmi',inplace=True)
plt.figure(figsize=(35,20))
plt.scatter(df['bmi'],df['charges'])
plt.plot(df['bmi'],df['pred'],c='r')

# %% [markdown]
# import xgboost as xg

# %%
import xgboost as xg
