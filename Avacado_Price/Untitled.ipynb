# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Avacado_Price.csv")
df=data.copy()
df
# Out:
#        AveragePrice  Total_Volume  tot_ava1   tot_ava2  tot_ava3  Total_Bags  \
# 0              1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1              1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2              0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3              1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4              1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...             ...           ...       ...        ...       ...         ...
# 18244          1.63      17074.83   2046.96    1529.20      0.00    13498.67
# 18245          1.71      13888.04   1191.70    3431.50      0.00     9264.84
# 18246          1.87      13766.76   1191.92    2452.79    727.94     9394.11
# 18247          1.93      16205.22   1527.63    2981.04    727.01    10969.54
# 18248          1.62      17489.58   2894.77    2356.13    224.53    12014.15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total_Volume  18249 non-null  float64
#  2   tot_ava1      18249 non-null  float64
#  3   tot_ava2      18249 non-null  float64
#  4   tot_ava3      18249 non-null  float64
#  5   Total_Bags    18249 non-null  float64
#  6   Small_Bags    18249 non-null  float64
#  7   Large_Bags    18249 non-null  float64
#  8   Xlarge_Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
duplicated=df.duplicated()

# %%
sum(duplicated)
# Out:
# 0

# %%
df.isna().sum()
# Out:
# AveragePrice    0
# Total_Volume    0
# tot_ava1        0
# tot_ava2        0
# tot_ava3        0
# Total_Bags      0
# Small_Bags      0
# Large_Bags      0
# Xlarge_Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.describe()
# Out:
#        AveragePrice  Total_Volume      tot_ava1      tot_ava2      tot_ava3  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total_Bags    Small_Bags    Large_Bags    Xlarge_Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
plt.hist(df.Total_Volume)
# Out:
# (array([1.7879e+04, 2.0100e+02, 0.0000e+00, 1.1000e+01, 4.7000e+01,
#         7.6000e+01, 2.9000e+01, 3.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([8.45600000e+01, 6.25064076e+06, 1.25011970e+07, 1.87517531e+07,
#         2.50023093e+07, 3.12528655e+07, 3.75034217e+07, 4.37539779e+07,
#         5.00045341e+07, 5.62550903e+07, 6.25056465e+07]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.AveragePrice)
# Out:
# (array([ 331., 2632., 4824., 4506., 3412., 1672.,  598.,  177.,   86.,
#           11.]),
#  array([0.44 , 0.721, 1.002, 1.283, 1.564, 1.845, 2.126, 2.407, 2.688,
#         2.969, 3.25 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df.Total_Volume)
plt.yticks(np.arange(1e6,7e7,0.3e7))
# Out:
# ([<matplotlib.axis.YTick at 0x2874c1e9ed0>,
# ...
#  [Text(0, 1000000.0, '0.1'),
#   Text(0, 4000000.0, '0.4'),
#   Text(0, 7000000.0, '0.7'),
#   Text(0, 10000000.0, '1.0'),
#   Text(0, 13000000.0, '1.3'),
#   Text(0, 16000000.0, '1.6'),
#   Text(0, 19000000.0, '1.9'),
#   Text(0, 22000000.0, '2.2'),
#   Text(0, 25000000.0, '2.5'),
#   Text(0, 28000000.0, '2.8'),
#   Text(0, 31000000.0, '3.1'),
#   Text(0, 34000000.0, '3.4'),
#   Text(0, 37000000.0, '3.7'),
#   Text(0, 40000000.0, '4.0'),
#   Text(0, 43000000.0, '4.3'),
#   Text(0, 46000000.0, '4.6'),
#   Text(0, 49000000.0, '4.9'),
#   Text(0, 52000000.0, '5.2'),
#   Text(0, 55000000.0, '5.5'),
#   Text(0, 58000000.0, '5.8'),
#   Text(0, 61000000.0, '6.1'),
#   Text(0, 64000000.0, '6.4'),
#   Text(0, 67000000.0, '6.7')])

# %%
plt.boxplot(df.AveragePrice)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2874ae73ad0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2874ae84d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2874adeda50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2874ae85d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2874ae86490>],
#  'means': []}

# %%
df.AveragePrice=df.AveragePrice<np.mean(df.AveragePrice)-np.std(df.AveragePrice)*3
df.AveragePrice=df.AveragePrice>np.mean(df.AveragePrice)+np.std(df.AveragePrice)*3

# %%
df
# Out:
#        AveragePrice  Total_Volume  tot_ava1   tot_ava2  tot_ava3  Total_Bags  \
# 0             False      64236.62   1036.74   54454.85     48.16     8696.87
# 1             False      54876.98    674.28   44638.81     58.33     9505.56
# 2             False     118220.22    794.70  109149.67    130.50     8145.35
# 3             False      78992.15   1132.00   71976.41     72.58     5811.16
# 4             False      51039.60    941.48   43838.39     75.78     6183.95
# ...             ...           ...       ...        ...       ...         ...
# 18244         False      17074.83   2046.96    1529.20      0.00    13498.67
# 18245         False      13888.04   1191.70    3431.50      0.00     9264.84
# 18246         False      13766.76   1191.92    2452.79    727.94     9394.11
# 18247         False      16205.22   1527.63    2981.04    727.01    10969.54
# 18248         False      17489.58   2894.77    2356.13    224.53    12014.15
#
# ...

# %%
df.AveragePrice>np.mean(df.AveragePrice)+np.std(df.AveragePrice)*3
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: AveragePrice, Length: 18249, dtype: bool
