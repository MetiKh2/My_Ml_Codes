# %%
import numpy as np
import pandas as pd

# %%
df_sale=pd.read_csv('Salesdata.csv')
df_store=pd.read_csv('store.csv')
# Out:
# DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df_store
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# ...                         ...                       ...     ...
# 1110                        6.0                    2014.0       1
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                 NaN              NaN               NaN
# 1                13.0           2010.0   Jan,Apr,Jul,Oct
# 2                14.0           2011.0   Jan,Apr,Jul,Oct
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 1110             31.0           2013.0   Jan,Apr,Jul,Oct
# 1111              NaN              NaN               NaN
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1115 rows x 10 columns]

# %%
df_sale
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  31-07-2015   5263        555     1      1
# 1            2          5  31-07-2015   6064        625     1      1
# 2            3          5  31-07-2015   8314        821     1      1
# 3            4          5  31-07-2015  13995       1498     1      1
# 4            5          5  31-07-2015   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  01-01-2013      0          0     0      0
# 1017205   1112          2  01-01-2013      0          0     0      0
# 1017206   1113          2  01-01-2013      0          0     0      0
# 1017207   1114          2  01-01-2013      0          0     0      0
# 1017208   1115          2  01-01-2013      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# 3                  0              1
# 4                  0              1
# ...              ...            ...
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1
#
# [1017209 rows x 9 columns]

# %%
from summarytools import dfSummary
dfSummary(df_sale)
# Out:
# <style type="text/css">
# #T_71c43 thead>tr>th {
#   text-align: left;
# }
# #T_71c43_row0_col0, #T_71c43_row1_col0, #T_71c43_row2_col0, #T_71c43_row3_col0, #T_71c43_row4_col0, #T_71c43_row5_col0, #T_71c43_row6_col0, #T_71c43_row7_col0, #T_71c43_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_71c43_row0_col1, #T_71c43_row1_col1, #T_71c43_row2_col1, #T_71c43_row3_col1, #T_71c43_row4_col1, #T_71c43_row5_col1, #T_71c43_row6_col1, #T_71c43_row7_col1, #T_71c43_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_71c43_row0_col2, #T_71c43_row1_col2, #T_71c43_row2_col2, #T_71c43_row3_col2, #T_71c43_row4_col2, #T_71c43_row5_col2, #T_71c43_row6_col2, #T_71c43_row7_col2, #T_71c43_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_71c43_row0_col3, #T_71c43_row1_col3, #T_71c43_row2_col3, #T_71c43_row3_col3, #T_71c43_row4_col3, #T_71c43_row5_col3, #T_71c43_row6_col3, #T_71c43_row7_col3, #T_71c43_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_71c43_row0_col4, #T_71c43_row1_col4, #T_71c43_row2_col4, #T_71c43_row3_col4, #T_71c43_row4_col4, #T_71c43_row5_col4, #T_71c43_row6_col4, #T_71c43_row7_col4, #T_71c43_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_71c43_row0_col5, #T_71c43_row1_col5, #T_71c43_row2_col5, #T_71c43_row3_col5, #T_71c43_row4_col5, #T_71c43_row5_col5, #T_71c43_row6_col5, #T_71c43_row7_col5, #T_71c43_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_71c43">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 1,017,209 x 9<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_71c43_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_71c43_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_71c43_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_71c43_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_71c43_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_71c43_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71c43_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_71c43_row0_col1" class="data row0 col1" ><strong>Store</strong><br>[int64]</td>
#       <td id="T_71c43_row0_col2" class="data row0 col2" >Mean (sd) : 558.4 (321.9)<br>min < med < max:<br>1.0 < 558.0 < 1115.0<br>IQR (CV) : 558.0 (1.7)</td>
#       <td id="T_71c43_row0_col3" class="data row0 col3" >1,115 distinct values</td>
#       <td id="T_71c43_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_71c43_row1_col1" class="data row1 col1" ><strong>DayOfWeek</strong><br>[int64]</td>
#       <td id="T_71c43_row1_col2" class="data row1 col2" >Mean (sd) : 4.0 (2.0)<br>min < med < max:<br>1.0 < 4.0 < 7.0<br>IQR (CV) : 4.0 (2.0)</td>
#       <td id="T_71c43_row1_col3" class="data row1 col3" >7 distinct values</td>
#       <td id="T_71c43_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_71c43_row2_col1" class="data row2 col1" ><strong>Date</strong><br>[object]</td>
#       <td id="T_71c43_row2_col2" class="data row2 col2" >1. 31-07-2015<br>2. 06-11-2013<br>3. 18-11-2013<br>4. 17-11-2013<br>5. 16-11-2013<br>6. 15-11-2013<br>7. 14-11-2013<br>8. 13-11-2013<br>9. 12-11-2013<br>10. 11-11-2013<br>11. other</td>
#       <td id="T_71c43_row2_col3" class="data row2 col3" >1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,115 (0.1%)<br>1,006,059 (98.9%)</td>
#       <td id="T_71c43_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_71c43_row3_col1" class="data row3 col1" ><strong>Sales</strong><br>[int64]</td>
#       <td id="T_71c43_row3_col2" class="data row3 col2" >Mean (sd) : 5773.8 (3849.9)<br>min < med < max:<br>0.0 < 5744.0 < 41551.0<br>IQR (CV) : 4129.0 (1.5)</td>
#       <td id="T_71c43_row3_col3" class="data row3 col3" >21,734 distinct values</td>
#       <td id="T_71c43_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_71c43_row4_col1" class="data row4 col1" ><strong>Customers</strong><br>[int64]</td>
#       <td id="T_71c43_row4_col2" class="data row4 col2" >Mean (sd) : 633.1 (464.4)<br>min < med < max:<br>0.0 < 609.0 < 7388.0<br>IQR (CV) : 432.0 (1.4)</td>
#       <td id="T_71c43_row4_col3" class="data row4 col3" >4,086 distinct values</td>
#       <td id="T_71c43_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_71c43_row5_col1" class="data row5 col1" ><strong>Open</strong><br>[int64]</td>
#       <td id="T_71c43_row5_col2" class="data row5 col2" >Mean (sd) : 0.8 (0.4)<br>min < med < max:<br>0.0 < 1.0 < 1.0<br>IQR (CV) : 0.0 (2.2)</td>
#       <td id="T_71c43_row5_col3" class="data row5 col3" >2 distinct values</td>
#       <td id="T_71c43_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_71c43_row6_col1" class="data row6 col1" ><strong>Promo</strong><br>[int64]</td>
#       <td id="T_71c43_row6_col2" class="data row6 col2" >Mean (sd) : 0.4 (0.5)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 1.0 (0.8)</td>
#       <td id="T_71c43_row6_col3" class="data row6 col3" >2 distinct values</td>
#       <td id="T_71c43_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_71c43_row7_col1" class="data row7 col1" ><strong>StateHoliday</strong><br>[object]</td>
#       <td id="T_71c43_row7_col2" class="data row7 col2" >1. 0<br>2. a<br>3. b<br>4. c</td>
#       <td id="T_71c43_row7_col3" class="data row7 col3" >986,159 (96.9%)<br>20,260 (2.0%)<br>6,690 (0.7%)<br>4,100 (0.4%)</td>
#       <td id="T_71c43_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_71c43_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_71c43_row8_col1" class="data row8 col1" ><strong>SchoolHoliday</strong><br>[int64]</td>
#       <td id="T_71c43_row8_col2" class="data row8 col2" >Mean (sd) : 0.2 (0.4)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 0.0 (0.5)</td>
#       <td id="T_71c43_row8_col3" class="data row8 col3" >2 distinct values</td>
#       <td id="T_71c43_row8_col4" class="data row8 col4" ><img src = "......"></img></td>
#       <td id="T_71c43_row8_col5" class="data row8 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfSummary(df_store)
# Out:
# <style type="text/css">
# #T_01b24 thead>tr>th {
#   text-align: left;
# }
# #T_01b24_row0_col0, #T_01b24_row1_col0, #T_01b24_row2_col0, #T_01b24_row3_col0, #T_01b24_row4_col0, #T_01b24_row5_col0, #T_01b24_row6_col0, #T_01b24_row7_col0, #T_01b24_row8_col0, #T_01b24_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_01b24_row0_col1, #T_01b24_row1_col1, #T_01b24_row2_col1, #T_01b24_row3_col1, #T_01b24_row4_col1, #T_01b24_row5_col1, #T_01b24_row6_col1, #T_01b24_row7_col1, #T_01b24_row8_col1, #T_01b24_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_01b24_row0_col2, #T_01b24_row1_col2, #T_01b24_row2_col2, #T_01b24_row3_col2, #T_01b24_row4_col2, #T_01b24_row5_col2, #T_01b24_row6_col2, #T_01b24_row7_col2, #T_01b24_row8_col2, #T_01b24_row9_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_01b24_row0_col3, #T_01b24_row1_col3, #T_01b24_row2_col3, #T_01b24_row3_col3, #T_01b24_row4_col3, #T_01b24_row5_col3, #T_01b24_row6_col3, #T_01b24_row7_col3, #T_01b24_row8_col3, #T_01b24_row9_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_01b24_row0_col4, #T_01b24_row1_col4, #T_01b24_row2_col4, #T_01b24_row3_col4, #T_01b24_row4_col4, #T_01b24_row5_col4, #T_01b24_row6_col4, #T_01b24_row7_col4, #T_01b24_row8_col4, #T_01b24_row9_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_01b24_row0_col5, #T_01b24_row1_col5, #T_01b24_row2_col5, #T_01b24_row3_col5, #T_01b24_row4_col5, #T_01b24_row5_col5, #T_01b24_row6_col5, #T_01b24_row7_col5, #T_01b24_row8_col5, #T_01b24_row9_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_01b24">
#   <caption><strong>Data Frame Summary</strong><br>___<br>Dimensions: 1,115 x 10<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_01b24_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_01b24_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_01b24_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_01b24_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_01b24_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_01b24_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_01b24_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_01b24_row0_col1" class="data row0 col1" ><strong>Store</strong><br>[int64]</td>
#       <td id="T_01b24_row0_col2" class="data row0 col2" >Mean (sd) : 558.0 (322.0)<br>min < med < max:<br>1.0 < 558.0 < 1115.0<br>IQR (CV) : 557.0 (1.7)</td>
#       <td id="T_01b24_row0_col3" class="data row0 col3" >1,115 distinct values</td>
#       <td id="T_01b24_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_01b24_row1_col1" class="data row1 col1" ><strong>StoreType</strong><br>[object]</td>
#       <td id="T_01b24_row1_col2" class="data row1 col2" >1. a<br>2. d<br>3. c<br>4. b</td>
#       <td id="T_01b24_row1_col3" class="data row1 col3" >602 (54.0%)<br>348 (31.2%)<br>148 (13.3%)<br>17 (1.5%)</td>
#       <td id="T_01b24_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_01b24_row2_col1" class="data row2 col1" ><strong>Assortment</strong><br>[object]</td>
#       <td id="T_01b24_row2_col2" class="data row2 col2" >1. a<br>2. c<br>3. b</td>
#       <td id="T_01b24_row2_col3" class="data row2 col3" >593 (53.2%)<br>513 (46.0%)<br>9 (0.8%)</td>
#       <td id="T_01b24_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_01b24_row3_col1" class="data row3 col1" ><strong>CompetitionDistance</strong><br>[float64]</td>
#       <td id="T_01b24_row3_col2" class="data row3 col2" >Mean (sd) : 5404.9 (7663.2)<br>min < med < max:<br>20.0 < 2325.0 < 75860.0<br>IQR (CV) : 6165.0 (0.7)</td>
#       <td id="T_01b24_row3_col3" class="data row3 col3" >654 distinct values</td>
#       <td id="T_01b24_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row3_col5" class="data row3 col5" >3<br>(0.3%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_01b24_row4_col1" class="data row4 col1" ><strong>CompetitionOpenSinceMonth</strong><br>[float64]</td>
#       <td id="T_01b24_row4_col2" class="data row4 col2" >Mean (sd) : 7.2 (3.2)<br>min < med < max:<br>1.0 < 8.0 < 12.0<br>IQR (CV) : 6.0 (2.2)</td>
#       <td id="T_01b24_row4_col3" class="data row4 col3" >12 distinct values</td>
#       <td id="T_01b24_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row4_col5" class="data row4 col5" >354<br>(31.7%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_01b24_row5_col1" class="data row5 col1" ><strong>CompetitionOpenSinceYear</strong><br>[float64]</td>
#       <td id="T_01b24_row5_col2" class="data row5 col2" >Mean (sd) : 2008.7 (6.2)<br>min < med < max:<br>1900.0 < 2010.0 < 2015.0<br>IQR (CV) : 7.0 (324.2)</td>
#       <td id="T_01b24_row5_col3" class="data row5 col3" >23 distinct values</td>
#       <td id="T_01b24_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row5_col5" class="data row5 col5" >354<br>(31.7%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_01b24_row6_col1" class="data row6 col1" ><strong>Promo2</strong><br>[int64]</td>
#       <td id="T_01b24_row6_col2" class="data row6 col2" >Mean (sd) : 0.5 (0.5)<br>min < med < max:<br>0.0 < 1.0 < 1.0<br>IQR (CV) : 1.0 (1.0)</td>
#       <td id="T_01b24_row6_col3" class="data row6 col3" >2 distinct values</td>
#       <td id="T_01b24_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_01b24_row7_col1" class="data row7 col1" ><strong>Promo2SinceWeek</strong><br>[float64]</td>
#       <td id="T_01b24_row7_col2" class="data row7 col2" >Mean (sd) : 23.6 (14.1)<br>min < med < max:<br>1.0 < 22.0 < 50.0<br>IQR (CV) : 24.0 (1.7)</td>
#       <td id="T_01b24_row7_col3" class="data row7 col3" >24 distinct values</td>
#       <td id="T_01b24_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row7_col5" class="data row7 col5" >544<br>(48.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_01b24_row8_col1" class="data row8 col1" ><strong>Promo2SinceYear</strong><br>[float64]</td>
#       <td id="T_01b24_row8_col2" class="data row8 col2" >1. nan<br>2. 2011.0<br>3. 2013.0<br>4. 2014.0<br>5. 2012.0<br>6. 2009.0<br>7. 2010.0<br>8. 2015.0</td>
#       <td id="T_01b24_row8_col3" class="data row8 col3" >544 (48.8%)<br>128 (11.5%)<br>120 (10.8%)<br>95 (8.5%)<br>81 (7.3%)<br>73 (6.5%)<br>64 (5.7%)<br>10 (0.9%)</td>
#       <td id="T_01b24_row8_col4" class="data row8 col4" ><img src = "......"></img></td>
#       <td id="T_01b24_row8_col5" class="data row8 col5" >544<br>(48.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_01b24_row9_col0" class="data row9 col0"

# %%
import sidetable

# %%
df_store.stb.freq(['StoreType'],style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8a9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8a9d_level0_col0" class="col_heading level0 col0" >StoreType</th>
#       <th id="T_d8a9d_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_d8a9d_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_d8a9d_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_d8a9d_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8a9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8a9d_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_d8a9d_row0_col1" class="data row0 col1" >602</td>
#       <td id="T_d8a9d_row0_col2" class="data row0 col2" >53.99%</td>
#       <td id="T_d8a9d_row0_col3" class="data row0 col3" >602</td>
#       <td id="T_d8a9d_row0_col4" class="data row0 col4" >53.99%</td>
#     </tr>
#     <tr>
#       <th id="T_d8a9d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8a9d_row1_col0" class="data row1 col0" >d</td>
#       <td id="T_d8a9d_row1_col1" class="data row1 col1" >348</td>
#       <td id="T_d8a9d_row1_col2" class="data row1 col2" >31.21%</td>
#       <td id="T_d8a9d_row1_col3" class="data row1 col3" >950</td>
#       <td id="T_d8a9d_row1_col4" class="data row1 col4" >85.20%</td>
#     </tr>
#     <tr>
#       <th id="T_d8a9d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8a9d_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_d8a9d_row2_col1" class="data row2 col1" >148</td>
#       <td id="T_d8a9d_row2_col2" class="data row2 col2" >13.27%</td>
#       <td id="T_d8a9d_row2_col3" class="data row2 col3" >1,098</td>
#       <td id="T_d8a9d_row2_col4" class="data row2 col4" >98.48%</td>
#     </tr>
#     <tr>
#       <th id="T_d8a9d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8a9d_row3_col0" class="data row3 col0" >b</td>
#       <td id="T_d8a9d_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_d8a9d_row3_col2" class="data row3 col2" >1.52%</td>
#       <td id="T_d8a9d_row3_col3" class="data row3 col3" >1,115</td>
#       <td id="T_d8a9d_row3_col4" class="data row3 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# import pandas as pd
import modin.pandas as pd

# %%
from pivottablejs import pivot_ui

pivot_ui(df_store)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import missingno as msno
msno.matrix(df_store)
# Out:
# <Axes: >

# %%
df_store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
from skimpy import skim

skim(df_store)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1115   │ │ float64     │ 5     │                                                          │
# │ │ Number of columns │ 10     │ │ string      │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column           ┃ NA  ┃ NA %             ┃ mean   ┃ sd     ┃ p0   ┃ p25   ┃ p50  ┃ p75   ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ Store            │   0 │                0 │    558 │    322 │    1 │ 279.5 │  558 │ 836.5 │  1115 │ ▇▇▇▇▇▇ │  │
# │ │ CompetitionDista │   3 │ 0.26905829596412 │   5405 │   7663 │   20 │ 717.5 │ 2325 │  6882 │ 75860 │   ▇▁   │  │
# │ │ nce              │     │              556 │        │        │      │       │      │       │       │        │  │
# │ │ CompetitionOpenS │ 354 │ 31.7488789237668 │  7.225 │  3.212 │    1 │     4 │    8 │    10 │    12 │ ▂▇▅▅▇▇ │  │
# │ │ inceMonth        │     │               17 │        │        │      │       │      │       │       │        │  │
# │ │ CompetitionOpenS │ 354 │ 31.7488789237668 │   2009 │  6.196 │ 1900 │  2006 │ 2010 │  2013 │  2015 │      ▇ │  │
# │ │ inceYear         │     │               17 │        │        │      │       │      │       │       │        │  │
# │ │ Promo2           │   0 │                0 │ 0.5121 │ 0.5001 │    0 │     0 │    1 │     1 │     1 │ ▇    ▇ │  │
# │ │ Promo2SinceWeek  │ 544 │ 48.7892376681614 │   23.6 │  14.14 │    1 │    13 │   22 │    37 │    50 │ ▅▇▃▃▇▂ │  │
# │ │                  │     │               34 │        │        │      │       │      │       │       │        │  │
# │ │ Promo2SinceYear  │ 544 │ 48.7892376681614 │   2012 │  1.675 │ 2009 │  2011 │ 2012 │  2013 │  2015 │ ▅▃▇▅▇▇ │  │
# │ │                  │     │               34 │        │        │      │       │      │       │       │        │  │
# │ └──────────────────┴─────┴──────────────────┴────────┴────────┴──────┴───────┴──────┴───────┴───────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃     ┃           ┃          ┃           ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA  ┃ NA %      ┃ shortest ┃ longest   ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ StoreTyp │   0 │         0 │ c        │ c         │ a        │ d         │        1 │         1 │     1115 │  │
# │ │ e        │     │           │          │           │          │           │          │           │          │  │
# │ │ Assortme │   0 │         0 │ a        │ a         │ a        │ c         │        1 │         1 │     1115 │  │
# │ │ nt       │     │           │          │           │          │           │          │           │          │  │
# │ │ PromoInt │ 544 │ 48.789237 │ Jan,Apr, │ Mar,Jun,S │ Feb,May, │ Mar,Jun,S │     15.2 │      0.51 │      571 │  │
# │ │ erval    │     │ 668161434 │ Jul,Oct  │ ept,Dec   │ Aug,Nov  │ ept,Dec   │          │           │          │  │
# │ └──────────┴─────┴───────────┴──────────┴───────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
from ydata_profiling import ProfileReport

# ایجاد پروفایل
profile = ProfileReport(df_store, title="Profiling Report")

# نمایش گزارش در نوت‌بوک
profile.to_notebook_iframe()
# profile.to_file("profiling_report.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       3 # ایجاد پروفایل
#       4 profile = ProfileReport(df_store, title="Profiling Report")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\profile_report.py:31
#      29 from ydata_profiling.model import BaseDescription
#      30 from ydata_profiling.model.alerts import AlertType
# ---> 31 from ydata_profiling.model.describe import describe as describe_df
#      32 from ydata_profiling.model.sample import Sample
#      33 from ydata_profiling.model.summarizer import (
#      34     BaseSummarizer,
#      35     PandasProfilingSummarizer,
#      36     format_summary,
#      37     redact_summary,
#      38 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\describe.py:20
#      18 from ydata_profiling.model.duplicates import get_duplicates
#      19 from ydata_profiling.model.missing import get_missing_active, get_missing_diagram
# ---> 20 from ydata_profiling.model.pairwise import get_scatter_plot, get_scatter_tasks
#      21 from ydata_profiling.model.sample import get_custom_sample, get_sample
#      22 from ydata_profiling.model.summarizer import BaseSummarizer
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\pairwise.py:6
#       3 import pandas as pd
#       5 from ydata_profiling.config import Settings
# ----> 6 from ydata_profiling.visualisation.plot import scatter_pairwise
#       9 def get_scatter_tasks(
#      10     config: Settings, continuous_variables: list
#      11 ) -> List[Tuple[Any, Any]]:
#      12     if not config.interactions.continuous:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\visualisation\plot.py:15
#      13 from matplotlib.patches import Patch
#      14 from matplotlib.ticker import FuncFormatter, MaxNLocator
# ---> 15 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#      16 from typeguard import typechecked
#      17 from wordcloud import WordCloud
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\graphics\tsaplots.py:11
#       8 import pandas as pd
#      10 from statsmodels.graphics import utils
# ---> 11 from statsmodels.tsa.stattools import acf, pacf
#      14 def _prepare_data_corr_plot(x, lags, zero):
#      15     zero = bool(zero)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\stattools.py:19
#      17 from scipy import stats
#      18 from scipy.interpolate import interp1d
# ---> 19 from scipy.signal import correlate
#      21 from statsmodels.regression.linear_model import OLS, yule_walker
#      22 from statsmodels.tools.sm_exceptions import (
#      23     CollinearityWarning,
#      24     InfeasibleTestError,
#      25     InterpolationWarning,
#      26     MissingDataError,
#      27 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\signal\__init__.py:327
#     325 from ._ltisys import *
#     326 from ._lti_conversion import *
# --> 327 from ._signaltools import *
#     328 from ._savitzky_golay import savgol_coeffs, savgol_filter
#     329 from ._spectral_py import *
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\signal\_signaltools.py:13
#      11 from scipy import linalg, fft as sp_fft
#      12 from scipy.fft._helper import _init_nd_shape_and_axes
# ---> 13 from scipy._lib._util import prod as _prod
#      14 import numpy as np
#      15 from scipy.special import lambertw
#
# ImportError: cannot import name 'prod' from 'scipy._lib._util' (C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\_lib\_util.py)
