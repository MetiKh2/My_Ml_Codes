# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('anaemia_dataset.csv')
df=data.copy()
df
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
df.drop(columns=['Number'],inplace=True)

# %%
df.describe()
# Out:
#        %Red Pixel  %Green pixel  %Blue pixel          Hb
# count  104.000000    104.000000   104.000000  104.000000
# mean    45.654175     28.875507    25.470325   12.150962
# std      2.816294      1.554275     1.984671    2.512957
# min     38.796800     25.140300    19.541300    2.800000
# 25%     43.911375     27.871300    24.896425   10.650000
# 50%     45.385350     28.948750    25.953200   12.600000
# 75%     46.968325     29.887275    26.721600   14.000000
# max     54.647800     32.368100    29.841400   16.300000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sex           104 non-null    object
#  1   %Red Pixel    104 non-null    float64
#  2   %Green pixel  104 non-null    float64
#  3   %Blue pixel   104 non-null    float64
#  4   Hb            104 non-null    float64
#  5   Anaemic       104 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 5.0+ KB

# %%
print(len(df[df['Sex']=='F']))
print(len(df[df['Sex']=='M']))
print(len(df[df['Sex']=='M ']))
# Out:
# 26
# 26
# 29

# %%
df['Sex'][df['Sex']=='M ']='M'
df['Sex'][df['Sex']=='F ']='F'

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_9628c thead>tr>th {
#   text-align: left;
# }
# #T_9628c_row0_col0, #T_9628c_row1_col0, #T_9628c_row2_col0, #T_9628c_row3_col0, #T_9628c_row4_col0, #T_9628c_row5_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_9628c_row0_col1, #T_9628c_row1_col1, #T_9628c_row2_col1, #T_9628c_row3_col1, #T_9628c_row4_col1, #T_9628c_row5_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_9628c_row0_col2, #T_9628c_row1_col2, #T_9628c_row2_col2, #T_9628c_row3_col2, #T_9628c_row4_col2, #T_9628c_row5_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_9628c_row0_col3, #T_9628c_row1_col3, #T_9628c_row2_col3, #T_9628c_row3_col3, #T_9628c_row4_col3, #T_9628c_row5_col3 {
#   text-align: left;
# ...

# %%
plt.pie([len(df[df['Sex']=='M']),len(df[df['Sex']=='F'])])
plt.title('Sex')
plt.legend(['Men','Women'])
plt.show() 
plt.pie([len(df[df['Anaemic']=='No']),len(df[df['Anaemic']=='Yes'])])
plt.title('Anaemic')
plt.legend(['No','Yes'])
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df,x='%Red Pixel',hue='Sex',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For %Red Pixel', size=15)
plt.show()
plt.figure(figsize=(15,7))
sns.histplot(df,x='%Red Pixel',hue='Anaemic',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For %Red Pixel', size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df,x='%Blue pixel',hue='Sex',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For %Blue Pixel', size=15)
plt.show()
plt.figure(figsize=(15,7))
sns.histplot(df,x='%Blue pixel',hue='Anaemic',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For %Blue Pixel', size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df,x='%Green pixel',hue='Sex',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For %Green Pixel', size=15)
plt.show()
plt.figure(figsize=(15,7))
sns.histplot(df,x='%Green pixel',hue='Anaemic',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For %Green Pixel', size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df,x='Hb',hue='Sex',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For Hb', size=15)
plt.show()
plt.figure(figsize=(15,7))
sns.histplot(df,x='Hb',hue='Anaemic',kde=True,color='skyblue',multiple="stack")
plt.title('Histogram For Hb', size=15)
plt.show()

# %%
sns.countplot(data=df, x='Anaemic', hue='Sex', alpha=1)
plt.title('Histogram For Gender vs disease',size=15)
# Out:
# Text(0.5, 1.0, 'Histogram For Gender vs disease')

# %%
#create histogram
df.hist(bins = 60, edgecolor = 'black', figsize = (15, 20))
#add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

#show plot
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2=df.copy()
df2['Anaemic']=le.fit_transform(df['Anaemic'])
df2['Sex']=le.fit_transform(df['Sex'])

# %%
df
# Out:
#     Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0     M     43.2555       30.8421      25.9025   6.3     Yes
# 1     F     45.6033       28.1900      26.2067  13.5      No
# 2     F     45.0107       28.9677      26.0215  11.7      No
# 3     F     44.5398       28.9899      26.4703  13.5      No
# 4     M     43.2870       30.6972      26.0158  12.4      No
# ..   ..         ...           ...          ...   ...     ...
# 99    F     49.9999       29.2860      20.7141  14.5     Yes
# 100   M     42.2324       30.6757      27.0919   6.3     Yes
# 101   F     45.6064       31.9084      22.4852  12.7      No
# 102   M     45.2095       29.2769      25.5136  13.4      No
# 103   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 6 columns]

# %%
df2
# Out:
#      Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb  Anaemic
# 0      1     43.2555       30.8421      25.9025   6.3        1
# 1      0     45.6033       28.1900      26.2067  13.5        0
# 2      0     45.0107       28.9677      26.0215  11.7        0
# 3      0     44.5398       28.9899      26.4703  13.5        0
# 4      1     43.2870       30.6972      26.0158  12.4        0
# ..   ...         ...           ...          ...   ...      ...
# 99     0     49.9999       29.2860      20.7141  14.5        1
# 100    1     42.2324       30.6757      27.0919   6.3        1
# 101    0     45.6064       31.9084      22.4852  12.7        0
# 102    1     45.2095       29.2769      25.5136  13.4        0
# 103    0     43.5706       29.8094      26.6199  12.2        0
#
# [104 rows x 6 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df2.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation",fontsize=20)
plt.show()

# %%
plt.scatter(df['%Green pixel'],df['%Red Pixel'])
plt.scatter(df['%Blue pixel'],df['%Red Pixel'])
plt.show()
plt.scatter(df['%Blue pixel'],df['%Green pixel'])

# %%
df_box = df.columns
i =  0
while i < len(df_box):
    fig = plt.figure(figsize = (25, 4), facecolor='burlywood')
    
    plt.subplot (1 , 2 , 1)
    box = sns.boxplot(x=df_box [i], data=df, palette="hot_r", width=0.5, dodge=True )
    box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
    box.set(xlabel=None)
    box.set_facecolor('white')
    plt.grid()
    i += 1

    if i < len(df_box):
        plt.subplot (1 , 2 , 2)
        box = sns.boxplot(x=df_box [i], data=df, palette="hot_r", width=0.5, dodge=True )
        box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
        box.set(xlabel=None)
        box.set_facecolor('white')
        plt.grid()
        i += 1

    plt.show()

# %%
x=df2.drop(columns='Anaemic')
y=df2['Anaemic'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print('Test:',logreg.score(x_test,y_test))
print('Training:',+logreg.score(x_train,y_train))
# Out:
# Test: 0.9230769230769231
# Training: 0.9743589743589743

# %%
y_pred=logreg.predict(x_test)

# %%
from sklearn.metrics import roc_curve
fpr,tpr,_=roc_curve(y_test,y_pred)
plt.plot(fpr,tpr)

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores
_, ax = plt.subplots()

# Create a cross-validation strategy
cv = StratifiedKFold(10)

# Create the cv score visualizer
oz = CVScores(
    LogisticRegression(), ax=ax, cv=cv, scoring='accuracy'
)
oz.fit(x_train, y_train)
oz.poof();

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test,y_pred)
# confusion metric visual
import seaborn as sn
plt.figure(figsize=(7,5))
cm_df = pd.DataFrame(cm,
                     index = ['No','Yes'], 
                     columns = ['No','Yes'])
sn.heatmap(cm_df,annot=True)

plt.xlabel('Predicted',color='black',size=15)
plt.ylabel('Truth',color='black',size=15)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
print('Test:',nb.score(x_test,y_test))
print('Training:',+nb.score(x_train,y_train))
# Out:
# Test: 0.9230769230769231
# Training: 0.9358974358974359

# %%
y_pred=nb.predict(x_test)

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores
_, ax = plt.subplots()

# Create a cross-validation strategy
cv = StratifiedKFold(10)

# Create the cv score visualizer
oz = CVScores(
    GaussianNB(), ax=ax, cv=cv, scoring='accuracy'
)
oz.fit(x_train, y_train)
oz.poof();

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test,y_pred)
# confusion metric visual
import seaborn as sn
plt.figure(figsize=(7,5))
cm_df = pd.DataFrame(cm,
                     index = ['No','Yes'], 
                     columns = ['No','Yes'])
sn.heatmap(cm_df,annot=True)

plt.xlabel('Predicted',color='black',size=15)
plt.ylabel('Truth',color='black',size=15)
plt.show()
