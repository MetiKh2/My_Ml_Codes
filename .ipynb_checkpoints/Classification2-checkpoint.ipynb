# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.express as px
# plt.style.use('seaborn-dark')
# plt.style.context('grayscale')
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('train.csv')
df=data.copy()
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
test = pd.read_csv('test.csv')
df_test=test.copy()
df_test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0      0.1        193  ...  16        226      1412  3476    12     7
# 1      0.8        191  ...  12        746       857  3895     6     0
# 2      0.9        186  ...   4       1270      1366  2396    17    10
# 3      0.5         96  ...  20        295      1752  3893    10     0
# 4      0.5        108  ...  18        749       810  1773    15     8
# ..     ...        ...  ...  ..        ...       ...   ...   ...   ...
# 995    0.5        170  ...  17        644       913  2121    14     8
# 996    0.9        186  ...   2       1152      1632  1933     8     1
# 997    0.5         80  ...  12        477       825  1223     5     0
# 998    0.4        171  ...  12         38       832  2509    15    11
# 999    0.1        140  ...  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# 0            2        0             1     0
# 1            7        1             0     0
# 2           10        0             1     1
# 3            7        1             1     0
# 4            7        1             0     1
# ..         ...      ...           ...   ...
# 995         15        1             1     0
# 996         19        0             1     1
# 997         14        1             0     0
# 998          6        0             1     0
# 999          3        1             0     1
#
# [1000 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.3 KB

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_aa5aa thead>tr>th {
#   text-align: left;
# }
# #T_aa5aa_row0_col0, #T_aa5aa_row1_col0, #T_aa5aa_row2_col0, #T_aa5aa_row3_col0, #T_aa5aa_row4_col0, #T_aa5aa_row5_col0, #T_aa5aa_row6_col0, #T_aa5aa_row7_col0, #T_aa5aa_row8_col0, #T_aa5aa_row9_col0, #T_aa5aa_row10_col0, #T_aa5aa_row11_col0, #T_aa5aa_row12_col0, #T_aa5aa_row13_col0, #T_aa5aa_row14_col0, #T_aa5aa_row15_col0, #T_aa5aa_row16_col0, #T_aa5aa_row17_col0, #T_aa5aa_row18_col0, #T_aa5aa_row19_col0, #T_aa5aa_row20_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_aa5aa_row0_col1, #T_aa5aa_row1_col1, #T_aa5aa_row2_col1, #T_aa5aa_row3_col1, #T_aa5aa_row4_col1, #T_aa5aa_row5_col1, #T_aa5aa_row6_col1, #T_aa5aa_row7_col1, #T_aa5aa_row8_col1, #T_aa5aa_row9_col1, #T_aa5aa_row10_col1, #T_aa5aa_row11_col1, #T_aa5aa_row12_col1, #T_aa5aa_row13_col1, #T_aa5aa_row14_col1, #T_aa5aa_row15_col1, #T_aa5aa_row16_col1, #T_aa5aa_row17_col1, #T_aa5aa_row18_col1, #T_aa5aa_row19_col1, #T_aa5aa_row20_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_aa5aa_row0_col2, #T_aa5aa_row1_col2, #T_aa5aa_row2_col2, #T_aa5aa_row3_col2, #T_aa5aa_row4_col2, #T_aa5aa_row5_col2, #T_aa5aa_row6_col2, #T_aa5aa_row7_col2, #T_aa5aa_row8_col2, #T_aa5aa_row9_col2, #T_aa5aa_row10_col2, #T_aa5aa_row11_col2, #T_aa5aa_row12_col2, #T_aa5aa_row13_col2, #T_aa5aa_row14_col2, #T_aa5aa_row15_col2, #T_aa5aa_row16_col2, #T_aa5aa_row17_col2, #T_aa5aa_row18_col2, #T_aa5aa_row19_col2, #T_aa5aa_row20_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_aa5aa_row0_col3, #T_aa5aa_row1_col3, #T_aa5aa_row2_col3, #T_aa5aa_row3_col3, #T_aa5aa_row4_col3, #T_aa5aa_row5_col3, #T_aa5aa_row6_col3, #T_aa5aa_row7_col3, #T_aa5aa_row8_col3, #T_aa5aa_row9_col3, #T_aa5aa_row10_col3, #T_aa5aa_row11_col3, #T_aa5aa_row12_col3, #T_aa5aa_row13_col3, #T_aa5aa_row14_col3, #T_aa5aa_row15_col3, #T_aa5aa_row16_col3, #T_aa5aa_row17_col3, #T_aa5aa_row18_col3, #T_aa5aa_row19_col3, #T_aa5aa_row20_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_aa5aa_row0_col4, #T_aa5aa_row1_col4, #T_aa5aa_row2_col4, #T_aa5aa_row3_col4, #T_aa5aa_row4_col4, #T_aa5aa_row5_col4, #T_aa5aa_row6_col4, #T_aa5aa_row7_col4, #T_aa5aa_row8_col4, #T_aa5aa_row9_col4, #T_aa5aa_row10_col4, #T_aa5aa_row11_col4, #T_aa5aa_row12_col4, #T_aa5aa_row13_col4, #T_aa5aa_row14_col4, #T_aa5aa_row15_col4, #T_aa5aa_row16_col4, #T_aa5aa_row17_col4, #T_aa5aa_row18_col4, #T_aa5aa_row19_col4, #T_aa5aa_row20_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_aa5aa_row0_col5, #T_aa5aa_row1_col5, #T_aa5aa_row2_col5, #T_aa5aa_row3_col5, #T_aa5aa_row4_col5, #T_aa5aa_row5_col5, #T_aa5aa_row6_col5, #T_aa5aa_row7_col5, #T_aa5aa_row8_col5, #T_aa5aa_row9_col5, #T_aa5aa_row10_col5, #T_aa5aa_row11_col5, #T_aa5aa_row12_col5, #T_aa5aa_row13_col5, #T_aa5aa_row14_col5, #T_aa5aa_row15_col5, #T_aa5aa_row16_col5, #T_aa5aa_row17_col5, #T_aa5aa_row18_col5, #T_aa5aa_row19_col5, #T_aa5aa_row20_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_aa5aa">
#   <caption><strong>Data Frame Summary</strong><br>___<br>Dimensions: 2,000 x 21<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_aa5aa_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_aa5aa_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_aa5aa_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_aa5aa_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_aa5aa_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_aa5aa_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aa5aa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_aa5aa_row0_col1" class="data row0 col1" ><strong>battery_power</strong><br>[int64]</td>
#       <td id="T_aa5aa_row0_col2" class="data row0 col2" >Mean (sd) : 1238.5 (439.4)<br>min < med < max:<br>501.0 < 1226.0 < 1998.0<br>IQR (CV) : 763.5 (2.8)</td>
#       <td id="T_aa5aa_row0_col3" class="data row0 col3" >1,094 distinct values</td>
#       <td id="T_aa5aa_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_aa5aa_row1_col1" class="data row1 col1" ><strong>blue</strong><br>[int64]</td>
#       <td id="T_aa5aa_row1_col2" class="data row1 col2" >1. 0<br>2. 1</td>
#       <td id="T_aa5aa_row1_col3" class="data row1 col3" >1,010 (50.5%)<br>990 (49.5%)</td>
#       <td id="T_aa5aa_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_aa5aa_row2_col1" class="data row2 col1" ><strong>clock_speed</strong><br>[float64]</td>
#       <td id="T_aa5aa_row2_col2" class="data row2 col2" >Mean (sd) : 1.5 (0.8)<br>min < med < max:<br>0.5 < 1.5 < 3.0<br>IQR (CV) : 1.5 (1.9)</td>
#       <td id="T_aa5aa_row2_col3" class="data row2 col3" >26 distinct values</td>
#       <td id="T_aa5aa_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_aa5aa_row3_col1" class="data row3 col1" ><strong>dual_sim</strong><br>[int64]</td>
#       <td id="T_aa5aa_row3_col2" class="data row3 col2" >1. 1<br>2. 0</td>
#       <td id="T_aa5aa_row3_col3" class="data row3 col3" >1,019 (50.9%)<br>981 (49.0%)</td>
#       <td id="T_aa5aa_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_aa5aa_row4_col1" class="data row4 col1" ><strong>fc</strong><br>[int64]</td>
#       <td id="T_aa5aa_row4_col2" class="data row4 col2" >Mean (sd) : 4.3 (4.3)<br>min < med < max:<br>0.0 < 3.0 < 19.0<br>IQR (CV) : 6.0 (1.0)</td>
#       <td id="T_aa5aa_row4_col3" class="data row4 col3" >20 distinct values</td>
#       <td id="T_aa5aa_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_aa5aa_row5_col1" class="data row5 col1" ><strong>four_g</strong><br>[int64]</td>
#       <td id="T_aa5aa_row5_col2" class="data row5 col2" >1. 1<br>2. 0</td>
#       <td id="T_aa5aa_row5_col3" class="data row5 col3" >1,043 (52.1%)<br>957 (47.9%)</td>
#       <td id="T_aa5aa_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_aa5aa_row6_col1" class="data row6 col1" ><strong>int_memory</strong><br>[int64]</td>
#       <td id="T_aa5aa_row6_col2" class="data row6 col2" >Mean (sd) : 32.0 (18.1)<br>min < med < max:<br>2.0 < 32.0 < 64.0<br>IQR (CV) : 32.0 (1.8)</td>
#       <td id="T_aa5aa_row6_col3" class="data row6 col3" >63 distinct values</td>
#       <td id="T_aa5aa_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_aa5aa_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_aa5aa_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_aa5aa_row7_col1" class="data row7 col1" ><strong>m_dep</strong><b

# %%
df.describe()[1:].T.style.background_gradient(cmap='magma', axis=1)
# Out:
# <style type="text/css">
# #T_16422_row0_col0 {
#   background-color: #bc3978;
#   color: #f1f1f1;
# }
# #T_16422_row0_col1, #T_16422_row1_col2, #T_16422_row1_col3, #T_16422_row1_col4, #T_16422_row2_col2, #T_16422_row3_col2, #T_16422_row3_col3, #T_16422_row4_col2, #T_16422_row5_col2, #T_16422_row5_col3, #T_16422_row6_col2, #T_16422_row7_col2, #T_16422_row8_col1, #T_16422_row9_col2, #T_16422_row10_col2, #T_16422_row11_col2, #T_16422_row12_col1, #T_16422_row13_col2, #T_16422_row14_col1, #T_16422_row15_col2, #T_16422_row16_col2, #T_16422_row17_col2, #T_16422_row18_col2, #T_16422_row18_col3, #T_16422_row19_col2, #T_16422_row19_col3, #T_16422_row20_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_16422_row0_col2 {
#   background-color: #050416;
#   color: #f1f1f1;
# }
# #T_16422_row0_col3 {
#   background-color: #56147d;
#   color: #f1f1f1;
# }
# #T_16422_row0_col4, #T_16422_row13_col4, #T_16422_row19_col0 {
#   background-color: #b83779;
#   color: #f1f1f1;
# }
# #T_16422_row0_col5 {
#   background-color: #fc8a62;
#   color: #f1f1f1;
# }
# #T_16422_row0_col6, #T_16422_row1_col5, #T_16422_row1_col6, #T_16422_row2_col6, #T_16422_row3_col4, #T_16422_row3_col5, #T_16422_row3_col6, #T_16422_row4_col6, #T_16422_row5_col4, #T_16422_row5_col5, #T_16422_row5_col6, #T_16422_row6_col6, #T_16422_row7_col6, #T_16422_row8_col6, #T_16422_row9_col6, #T_16422_row10_col6, #T_16422_row11_col6, #T_16422_row12_col6, #T_16422_row13_col6, #T_16422_row14_col6, #T_16422_row15_col6, #T_16422_row16_col6, #T_16422_row17_col3, #T_16422_row17_col4, #T_16422_row17_col5, #T_16422_row17_col6, #T_16422_row18_col4, #T_16422_row18_col5, #T_16422_row18_col6, #T_16422_row19_col4, #T_16422_row19_col5, #T_16422_row19_col6, #T_16422_row20_col6 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_16422_row1_col0, #T_16422_row10_col0 {
#   background-color: #b3367a;
#   color: #f1f1f1;
# }
# #T_16422_row1_col1, #T_16422_row3_col1, #T_16422_row9_col0, #T_16422_row10_col4, #T_16422_row15_col5, #T_16422_row16_col0, #T_16422_row16_col4, #T_16422_row18_col0, #T_16422_row18_col1, #T_16422_row19_col1, #T_16422_row20_col0, #T_16422_row20_col4 {
#   background-color: #b73779;
#   color: #f1f1f1;
# }
# #T_16422_row2_col0 {
#   background-color: #902a81;
#   color: #f1f1f1;
# }
# #T_16422_row2_col1 {
#   background-color: #1d1147;
#   color: #f1f1f1;
# }
# #T_16422_row2_col3 {
#   background-color: #0e0b2b;
#   color: #f1f1f1;
# }
# #T_16422_row2_col4 {
#   background-color: #8c2981;
#   color: #f1f1f1;
# }
# #T_16422_row2_col5 {
#   background-color: #f4675c;
#   color: #f1f1f1;
# }
# #T_16422_row3_col0 {
#   background-color: #ba3878;
#   color: #f1f1f1;
# }
# #T_16422_row4_col0, #T_16422_row4_col1 {
#   background-color: #471078;
#   color: #f1f1f1;
# }
# #T_16422_row4_col3, #T_16422_row14_col2 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_16422_row4_col4 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# #T_16422_row4_col5 {
#   background-color: #802582;
#   color: #f1f1f1;
# }
# #T_16422_row5_col0, #T_16422_row12_col0, #T_16422_row12_col4 {
#   background-color: #bf3a77;
#   color: #f1f1f1;
# }
# #T_16422_row5_col1, #T_16422_row13_col0 {
#   background-color: #b5367a;
#   color: #f1f1f1;
# }
# #T_16422_row6_col0 {
#   background-color: #b0357b;
#   color: #f1f1f1;
# }
# #T_16422_row6_col1 {
#   background-color: #54137d;
#   color: #f1f1f1;
# }
# #T_16422_row6_col3, #T_16422_row11_col1 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_16422_row6_col4, #T_16422_row11_col5 {
#   background-color: #ae347b;
#   color: #f1f1f1;
# }
# #T_16422_row6_col5 {
#   background-color: #fb835f;
#   color: #f1f1f1;
# }
# #T_16422_row7_col0, #T_16422_row8_col3 {
#   background-color: #a02f7f;
#   color: #f1f1f1;
# }
# #T_16422_row7_col1 {
#   background-color: #3f0f72;
#   color: #f1f1f1;
# }
# #T_16422_row7_col3, #T_16422_row15_col3 {
#   background-color: #180f3d;
#   color: #f1f1f1;
# }
# #T_16422_row7_col4 {
#   background-color: #9e2f7f;
#   color: #f1f1f1;
# }
# #T_16422_row7_col5, #T_16422_row16_col5 {
#   background-color: #fd9668;
#   color: #000000;
# }
# #T_16422_row8_col0 {
#   background-color: #ea5661;
#   color: #f1f1f1;
# }
# #T_16422_row8_col2 {
#   background-color: #59157e;
#   color: #f1f1f1;
# }
# #T_16422_row8_col4 {
#   background-color: #eb5760;
#   color: #f1f1f1;
# }
# #T_16422_row8_col5 {
#   background-color: #fea973;
#   color: #000000;
# }
# #T_16422_row9_col1 {
#   background-color: #341069;
#   color: #f1f1f1;
# }
# #T_16422_row9_col3, #T_16422_row11_col4 {
#   background-color: #5f187f;
#   color: #f1f1f1;
# }
# #T_16422_row9_col4, #T_16422_row17_col1 {
#   background-color: #982d80;
#   color: #f1f1f1;
# }
# #T_16422_row9_col5 {
#   background-color: #febb81;
#   color: #000000;
# }
# #T_16422_row10_col1 {
#   background-color: #651a80;
#   color: #f1f1f1;
# }
# #T_16422_row10_col3, #T_16422_row20_col3 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_16422_row10_col5, #T_16422_row13_col5, #T_16422_row20_col5 {
#   background-color: #fc8961;
#   color: #f1f1f1;
# }
# #T_16422_row11_col0 {
#   background-color: #701f81;
#   color: #f1f1f1;
# }
# #T_16422_row11_col3 {
#   background-color: #221150;
#   color: #f1f1f1;
# }
# #T_16422_row12_col2 {
#   background-color: #060518;
#   color: #f1f1f1;
# }
# #T_16422_row12_col3 {
#   background-color: #5d177f;
#   color: #f1f1f1;
# }
# #T_16422_row12_col5 {
#   background-color: #fc9065;
#   color: #000000;
# }
# #T_16422_row13_col1, #T_16422_row16_col3 {
#   background-color: #440f76;
#   color: #f1f1f1;
# }
# #T_16422_row13_col3 {
#   background-color: #52137c;
#   color: #f1f1f1;
# }
# #T_16422_row14_col0 {
#   background-color: #ca3e72;
#   color: #f1f1f1;
# }
# #T_16422_row14_col3, #T_16422_row15_col0 {
#   background-color: #6d1d81;
#   color: #f1f1f1;
# }
# #T_16422_row14_col4 {
#   background-color: #c03a76;
#   color: #f1f1f1;
# }
# #T_16422_row14_col5 {
#   background-color: #fe9f6d;
#   color: #000000;
# }
# #T_16422_row15_col1 {
#   background-color: #4c117a;
#   color: #f1f1f1;
# }
# #T_16422_row15_col4 {
#   background-color: #5c167f;
#   color: #f1f1f1;
# }
# #T_16422_row16_col1 {
#   background-color: #38106c;
#   color: #f1f1f1;
# }
# #T_16422_row17_col0 {
#   background-color: #fc8c63;
#   color: #f1f1f1;
# }
# #T_16422_row20_col1 {
#   background-color: #812581;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16422">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16422_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_16422_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_16422_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_16422_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_16422_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_16422_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_16422_level0_col6" class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16422_level0_row0" class="row_heading level0 row0" >battery_power</th>
#       <td id="T_16422_row0_col0" class="data row0 col0" >1238.518500</td>
#       <td id="T_16422_row0_col1" class="data row0 col1" >439.418206</td>
#       <td id="T_16422_row0_col2" class="data row0 col2" >501.000000</td>
#       <td id="T_16422_row0_col3" class="data row0 col3" >851.750000</td>
#       <td id="T_16422_row0_col4" class="data row0 col4" >1226.000000</td>
#       <td id="T_16422_row0_col5" class="data row0 col5" >1615.250000</td>
#       <td id="T_16422_row0_col6" class="data row0 col6" >1998.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16422_level0_row1" class="row_heading level0 row1" >blue</th>
#       <td id="T_16422_row1_col0" class="data row1 col0" >0.495000</td>
#       <td id="T_16422_row1_col1" class="data row1 col1" >0.500100</td>
#       <td id="T_16422_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_16422_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_16422_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_16422_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_16422_row1_col6" class="data row1 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16422_level0_row2" class="row_heading level0 row2" >clock_speed</th>
#       <td id="T_16422_row2_col0" class="data row2 col0" >1.522250</td>
#       <td id="T

# %%
print('Number of duplicated rows: ' , len(df[df.duplicated()]))
# Out:
# Number of duplicated rows:  0

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
from matplotlib.colors import ListedColormap

custom_cmap = ListedColormap(['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']) 
plt.figure(figsize=(22,4))
sns.heatmap((df.isna().sum()).to_frame(name='').T, annot=True,
            ).set_title('Count of Missing Values', fontsize=18)
plt.show()

# %%
import missingno as msno
import matplotlib.pyplot as plt
msno.bar(data)
plt.show()

# %%
import missingno as msno
import matplotlib.pyplot as plt
msno.bar(data)
plt.show()

# %%
#create histogram
df.hist(bins = 10, edgecolor = 'black', figsize = (15, 20))

#add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

#show plot
plt.show()

# %%
corr=df.corr()
fig = plt.figure(figsize=(15,12))
r = sns.heatmap(corr, cmap='Oranges', annot=True, fmt=".2f")
r.set_title("Correlation ")
# Out:
# Text(0.5, 1.0, 'Correlation ')

# %%
corr.sort_values(by=["price_range"],ascending=False).iloc[0].sort_values(ascending=False)
# Out:
# price_range      1.000000
# ram              0.917046
# battery_power    0.200723
# px_width         0.165818
# px_height        0.148858
# int_memory       0.044435
# sc_w             0.038711
# pc               0.033599
# three_g          0.023611
# sc_h             0.022986
# fc               0.021998
# talk_time        0.021859
# blue             0.020573
# wifi             0.018785
# dual_sim         0.017444
# four_g           0.014772
# n_cores          0.004399
# m_dep            0.000853
# clock_speed     -0.006606
# mobile_wt       -0.030302
# touch_screen    -0.030411
# Name: price_range, dtype: float64

# %%
plt.figure(figsize=(6, 6))
heatmap = sns.heatmap(df.corr()[['price_range']].sort_values(by='price_range', ascending=False), vmin=-1, vmax=1, annot=True, cmap='RdYlGn')
heatmap.set_title('Features Correlating with price_range', fontdict={'fontsize':18}, pad=16);

# %%
scatter_plot = list (df.drop ("price_range" , axis = 1))               
i =  0
while i < 20:
    plt.figure (figsize = [10 , 4])
    plt.subplot (1 , 2 , 1)   
    plt.scatter (df [scatter_plot [i]] , df ["price_range"] , alpha = .5)
    plt.title (scatter_plot [i] + " vs price_range")
    plt.xlabel (scatter_plot [i])
    plt.xticks (rotation = 90)
    plt.ylabel ("price_range")
    plt.grid ()
    i += 1
    plt.subplot (1 , 2 , 2)
    plt.scatter (df [scatter_plot [i]] , df ["price_range"] , alpha = .5)
    plt.title (scatter_plot [i] + " vs price_range")
    plt.xlabel (scatter_plot [i])
    plt.xticks (rotation = 90)
    plt.ylabel ("price_range")
    plt.grid ()
    i += 1
    plt.show ()

# %%
labels = df["price_range"].value_counts().index
sizes = df["price_range"].value_counts()
colors = ['blue', 'red', 'purple', 'gold', 'lime', 'teal']
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=90)
plt.title('COSTS',color = 'green',fontsize = 15)
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(10,10))
plt.title("Battery power by price")
sns.set(font_scale=1)
sns.barplot(data=df, y="battery_power",x="price_range",palette="viridis")
plt.show()

# %%
count_plot_columns = list (df.drop (['battery_power' , 'mobile_wt' , 'px_height', 'px_width' , 'ram'] , axis = 1))
i =  0

while i < len(count_plot_columns):
    fig = plt.figure(figsize = (20, 7), facecolor='chocolate')
    
    plt.subplot(1, 2, 1)
    sns.countplot(x=count_plot_columns[i], data=df)
    plt.title(f'Counts of {count_plot_columns[i]}', fontsize=20)  
    plt.grid ()
    plt.gca().set_facecolor('chocolate')
    i += 1

    if i < len(count_plot_columns):
        plt.subplot(1, 2, 2)
        sns.countplot(x=count_plot_columns[i], data=df)
        plt.title(f'Counts of {count_plot_columns[i]}', fontsize=20) 
        plt.grid ()
        plt.gca().set_facecolor('chocolate')
        i += 1

    plt.show()

# %%
df_box = df[['battery_power' , 'mobile_wt' , 'px_height', 'px_width' , 'ram' , 'clock_speed' , 'fc' , 'int_memory' , 'pc' , 'm_dep' , 'talk_time']].columns
i =  0
while i < len(df_box):
    fig = plt.figure(figsize = (25, 4), facecolor='burlywood')
    
    plt.subplot (1 , 2 , 1)
    box = sns.boxplot(x=df_box [i], data=df, palette="hot_r", width=0.5, dodge=True )
    box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
    box.set(xlabel=None)
    box.set_facecolor('white')
    plt.grid()
    i += 1

    if i < len(df_box):
        plt.subplot (1 , 2 , 2)
        box = sns.boxplot(x=df_box [i], data=df, palette="hot_r", width=0.5, dodge=True )
        box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
        box.set(xlabel=None)
        box.set_facecolor('white')
        plt.grid()
        i += 1

    plt.show()

# %%
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="touch_screen", y="ram", hue="price_range",
              data=data, dodge=True, jitter=True,
              alpha=.25, zorder=1)

# Show the conditional means

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend( title="Price Range",
          handletextpad=0, columnspacing=1,
          loc="best", ncol=2, frameon=True);

# %%
plt.figure(figsize = (10, 6))
sns.violinplot(x = 'price_range', y = 'ram', data = df, palette = 'Set3')
plt.title('Violin Plot of Ram by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Ram')
plt.show()

# %%
plt.figure(figsize = (20, 10))
sns.countplot(x = 'blue', hue = 'price_range', data = df, palette = 'Dark2')
plt.title(f'Count of Bluetooth by Price Range')
plt.xlabel('Bluetooth')
plt.ylabel('Count')
plt.legend(title = 'Price Range', labels = ['Low', 'Medium', 'High', 'Very High']);

# %%
y = data["price_range"].values.reshape(-1,1)
x=data.drop(["price_range"],axis=1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25,random_state=42)

# %%
# from yellowbrick.target import ClassBalance
# visualizer = ClassBalance(labels=[0, 1, 2, 3])
# visualizer.fit(y_train, y_test)
# visualizer.poof();

# %%
svm=SVC()
svm.fit(x_train,y_train)
print("train accuracy:",svm.score(x_train,y_train))
print("test accuracy:",svm.score(x_test,y_test))
# Out:
# train accuracy: 0.9553333333333334
# test accuracy: 0.952

# %%
C = [0.01, 0.1, 0.25, 0.5, 1, 2, 5, 10]  
kernel = ["linear", "rbf", "poly", "sigmoid"] 
gamma = ["scale", "auto", 0.1, 0.01, 0.001, 0.0001, 1, 2]  
decision_function_shape = ["ovo", "ovr"]

# %%
# svm=SVC()
# grid_svm=GridSearchCV(estimator=svm,cv=5,param_grid=dict(kernel=kernel,
#                                                          C=C,
#                                                          # gamma=gamma,
#                                                          # decision_function_shape=decision_function_shape
#                                                         ))
# grid_svm.fit(x_train,y_train)
# print("best score: ", grid_svm.best_score_)
# print("best param: ", grid_svm.best_params_)

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores
_, ax = plt.subplots()

# Create a cross-validation strategy
cv = StratifiedKFold(10)

# Create the cv score visualizer
oz = CVScores(
    SVC(C=10,decision_function_shape="ovo", gamma="scale", kernel="poly",random_state=42), ax=ax, cv=cv, scoring='accuracy'
)
oz.fit(x_train, y_train)
oz.poof();

# %%
svm_model=SVC(C=10, decision_function_shape="ovo",
              gamma="scale",kernel="poly")
svm_model.fit(x_train, y_train)
print("train_accuracy:",svm_model.score(x_train,y_train))
print("test_accuracy: ", svm_model.score(x_test,y_test))
# Out:
# train_accuracy: 0.972
# test_accuracy:  0.966

# %%
from yellowbrick.classifier import ConfusionMatrix
import matplotlib.pyplot as plt
cm = ConfusionMatrix(
    svm_model, classes=[0,1,2,3]
)

cm.fit(x_train, y_train)
cm.score(x_test, y_test)

cm.poof();

# %%
y_pred= svm_model.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.966
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       132
#            1       0.92      0.99      0.96       118
#            2       0.96      0.93      0.95       120
#            3       0.98      0.97      0.98       130
#
#     accuracy                           0.97       500
#    macro avg       0.97      0.97      0.97       500
# weighted avg       0.97      0.97      0.97       500

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100)

rf_model.fit(x_train, y_train)

rf_train_accuracy = rf_model.score(x_train, y_train)
rf_test_accuracy = rf_model.score(x_test, y_test)

print("Random Forest Train Accuracy:", rf_train_accuracy)
print("Random Forest Test Accuracy:", rf_test_accuracy)
# Out:
# Random Forest Train Accuracy: 1.0
# Random Forest Test Accuracy: 0.87

# %%
from sklearn.model_selection import GridSearchCV

n_estimators = [50, 100, 200, 300, 500]  
max_depth = [None, 10, 20, 30, 40]  
min_samples_split = [2, 5, 10]  
min_samples_leaf = [1, 2, 4]  
bootstrap = [True, False]  

param_grid = {
    'n_estimators': n_estimators,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    # 'min_samples_leaf': min_samples_leaf,
    # 'bootstrap': bootstrap
}

# %%
# from sklearn.ensemble import RandomForestClassifier

# rf = RandomForestClassifier(random_state=42)

# grid_rf = GridSearchCV(estimator=rf,
#                        param_grid=param_grid,
#                        cv=10,
#                        verbose=0,
#                        n_jobs=-1)
# grid_rf.fit(x_train, y_train)

# print("Best score:", grid_rf.best_score_)
# print("Best params:", grid_rf.best_params_)
# Out:
# Best score: 0.884
# Best params: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 500}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores
import matplotlib.pyplot as plt

_, ax = plt.subplots()

# Create a cross-validation strategy
cv = StratifiedKFold(10)

# Create the cv score visualizer
oz = CVScores(
    RandomForestClassifier(
        n_estimators=500, 
        max_depth=None,
        min_samples_split=5,
        min_samples_leaf=1,
        bootstrap=False,
        random_state=42
    ),
    ax=ax,
    cv=cv,
    scoring='accuracy'
)

# Fit and visualize
oz.fit(x_train, y_train)
oz.poof();

# %%
rf_model= RandomForestClassifier(n_estimators= 500, max_depth=None, 
                                 min_samples_split=5,min_samples_leaf=1, 
                                 bootstrap=False, 
                                 random_state=42)
rf_model.fit(x_train, y_train)
print("train_accuracy:", rf_model.score(x_train,y_train))
print("test_accuracy: ", rf_model.score(x_test,y_test))
# Out:
# train_accuracy: 1.0
# test_accuracy:  0.88

# %%
from yellowbrick.classifier import ConfusionMatrix
import matplotlib.pyplot as plt
cm = ConfusionMatrix(
    rf_model, classes=[0,1,2,3]
)

cm.fit(x_train, y_train)
cm.score(x_test, y_test)

cm.poof();

# %%
y_pred= rf_model.predict(x_test)
from sklearn.metrics import classification_report, accuracy_score

print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.88
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93       132
#            1       0.83      0.85      0.84       118
#            2       0.83      0.82      0.82       120
#            3       0.93      0.91      0.92       130
#
#     accuracy                           0.88       500
#    macro avg       0.88      0.88      0.88       500
# weighted avg       0.88      0.88      0.88       500

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)

dt_model.fit(x_train, y_train)

dt_train_accuracy = dt_model.score(x_train, y_train)
dt_test_accuracy = dt_model.score(x_test, y_test)

print("Decision Tree Train Accuracy:", dt_train_accuracy)
print("Decision Tree Test Accuracy:", dt_test_accuracy)
# Out:
# Decision Tree Train Accuracy: 1.0
# Decision Tree Test Accuracy: 0.804

# %%
param_grid = {'criterion' :['gini', 'entropy'] , 
              'max_depth' :[None, 5, 10, 20, 30, 50] , 
             'min_samples_split' : [2, 5, 10, 20] ,
             'min_samples_leaf' : [1, 2, 4, 10] 
             }

# %%
dt = DecisionTreeClassifier(random_state = 42)

grid_dt = GridSearchCV(estimator= dt, param_grid= param_grid, cv= 5, verbose= 0, n_jobs= -1)
grid_dt.fit(x_train, y_train)

print("Best score:", grid_dt.best_score_)
print("Best params:", grid_dt.best_params_)
# Out:
# Best score: 0.858
# Best params: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
# Create a cross-validation strategy
cv = StratifiedKFold(10)

# Create the cv score visualizer
oz = CVScores(
    DecisionTreeClassifier(
        criterion="entropy", 
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=2,
        random_state=42
    ),
    ax=ax,
    cv=cv,
    scoring='accuracy'
)

# Fit and visualize
oz.fit(x_train, y_train)
oz.poof();

# %%
dt_model= DecisionTreeClassifier(criterion= "entropy", max_depth=None, 
                                 min_samples_split=2,min_samples_leaf=2, 
                                 random_state=42)
dt_model.fit(x_train, y_train)
print("train_accuracy:", dt_model.score(x_train,y_train))
print("test_accuracy: ", dt_model.score(x_test,y_test))
# Out:
# train_accuracy: 0.9846666666666667
# test_accuracy:  0.86

# %%
from yellowbrick.classifier import ConfusionMatrix
import matplotlib.pyplot as plt

cm = ConfusionMatrix(
    dt_model, classes=[0,1,2,3]
)

cm.fit(x_train, y_train)
cm.score(x_test, y_test)

cm.poof();

# %%
y_pred= dt_model.predict(x_test)
from sklearn.metrics import classification_report, accuracy_score

print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.86
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       132
#            1       0.81      0.86      0.83       118
#            2       0.79      0.78      0.79       120
#            3       0.90      0.87      0.88       130
#
#     accuracy                           0.86       500
#    macro avg       0.86      0.86      0.86       500
# weighted avg       0.86      0.86      0.86       500

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='mlogloss')

xgb_model.fit(x_train, y_train)

xgb_train_accuracy = xgb_model.score(x_train, y_train)
xgb_test_accuracy = xgb_model.score(x_test, y_test)

print("XGBoost Train Accuracy:", xgb_train_accuracy)
print("XGBoost Test Accuracy:", xgb_test_accuracy)
# Out:
# XGBoost Train Accuracy: 1.0
# XGBoost Test Accuracy: 0.894

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [50, 100, 200],
    'subsample': [0.6, 0.8, 1],
    # 'colsample_bytree': [0.6, 0.8, 1],
    # 'reg_alpha': [0, 0.5, 1],
    # 'reg_lambda': [1, 2, 3]
}

# %%
grid_xgb = GridSearchCV(estimator=XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='mlogloss'),
                        param_grid=param_grid, 
                        cv=5, 
                        scoring='accuracy', 
                        verbose=0, 
                        n_jobs=-1)

grid_xgb.fit(x_train, y_train)

print("Best score:", grid_xgb.best_score_)
print("Best params:", grid_xgb.best_params_)
# Out:
# Best score: 0.9106666666666667
# Best params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.6}

# %%
_, ax = plt.subplots()

# Create a cross-validation strategy
cv = StratifiedKFold(10)

# Create the cv score visualizer
oz = CVScores(
    XGBClassifier(
       colsapmle_bytree = 0.8, 
        learning_rate= 0.1,
        max_depth= 5,
        n_estimators= 200,
        reg_alpha= 0.5,
        reg_lambda= 1,
        subsample= 0.6,
        random_state=42
    ),
    ax=ax,
    cv=cv,
    scoring='accuracy'
)

# Fit and visualize
oz.fit(x_train, y_train)
oz.poof();

# %%
xgb_model= XGBClassifier(colsample_bytree= 0.8, learning_rate= 0.1, 
                                 max_depth= 5, n_estimators= 200, 
                                 reg_alpha= 0.5,
                                 reg_lambda= 1,
                                 subsample= 0.6,
                                 random_state=42)

# %%
xgb_model.fit(x_train, y_train)
print("train_accuracy:", xgb_model.score(x_train,y_train))
print("test_accuracy: ", xgb_model.score(x_test,y_test))
# Out:
# train_accuracy: 1.0
# test_accuracy:  0.904

# %%
from yellowbrick.classifier import ConfusionMatrix
import matplotlib.pyplot as plt

cm = ConfusionMatrix(
    xgb_model, classes=[0,1,2,3]
)

cm.fit(x_train, y_train)
cm.score(x_test, y_test)

cm.poof();

# %%
y_pred= xgb_model.predict(x_test)

print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.904
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       132
#            1       0.86      0.91      0.88       118
#            2       0.87      0.84      0.86       120
#            3       0.93      0.92      0.92       130
#
#     accuracy                           0.90       500
#    macro avg       0.90      0.90      0.90       500
# weighted avg       0.90      0.90      0.90       500

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Tüm modellerin skorlarını toplamak için liste
model_results = []

# SVM Performansı
svm_test_pred = svm_model.predict(x_test)
model_results.append({
    'Model': 'SVM',
    'Train Accuracy': svm_model.score(x_train, y_train),
    'Test Accuracy': accuracy_score(y_test, svm_test_pred),
    'Precision': precision_score(y_test, svm_test_pred, average='weighted'),
    'Recall': recall_score(y_test, svm_test_pred, average='weighted'),
    'F1-Score': f1_score(y_test, svm_test_pred, average='weighted')
})

# Decision Tree Performansı
dt_test_pred = dt_model.predict(x_test)
model_results.append({
    'Model': 'Decision Tree',
    'Train Accuracy': dt_model.score(x_train, y_train),
    'Test Accuracy': accuracy_score(y_test, dt_test_pred),
    'Precision': precision_score(y_test, dt_test_pred, average='weighted'),
    'Recall': recall_score(y_test, dt_test_pred, average='weighted'),
    'F1-Score': f1_score(y_test, dt_test_pred, average='weighted')
})

# Random Forest Performansı
rf_test_pred = rf_model.predict(x_test)
model_results.append({
    'Model': 'Random Forest',
    'Train Accuracy': rf_model.score(x_train, y_train),
    'Test Accuracy': accuracy_score(y_test, rf_test_pred),
    'Precision': precision_score(y_test, rf_test_pred, average='weighted'),
    'Recall': recall_score(y_test, rf_test_pred, average='weighted'),
    'F1-Score': f1_score(y_test, rf_test_pred, average='weighted')
})

# XGBoost Performansı
xgb_test_pred = xgb_model.predict(x_test)
model_results.append({
    'Model': 'XGBoost',
    'Train Accuracy': xgb_model.score(x_train, y_train),
    'Test Accuracy': accuracy_score(y_test, xgb_test_pred),
    'Precision': precision_score(y_test, xgb_test_pred, average='weighted'),
    'Recall': recall_score(y_test, xgb_test_pred, average='weighted'),
    'F1-Score': f1_score(y_test, xgb_test_pred, average='weighted')
})

# Sonuçları bir DataFrame olarak göster
import pandas as pd
results_df = pd.DataFrame(model_results)
print(results_df)
# Out:
#            Model  Train Accuracy  Test Accuracy  Precision  Recall  F1-Score
# 0            SVM        0.972000          0.966   0.967098   0.966  0.966131
# 1  Decision Tree        0.984667          0.860   0.860843   0.860  0.860237
# 2  Random Forest        1.000000          0.880   0.880237   0.880  0.880027
# 3        XGBoost        1.000000          0.904   0.904329   0.904  0.903963

# %%
from sklearn.metrics import ConfusionMatrixDisplay

models = [('SVM', svm_test_pred), 
          ('Decision Tree', dt_test_pred), 
          ('Random Forest', rf_test_pred), 
          ('XGBoost', xgb_test_pred)]

for model_name, predictions in models:
    ConfusionMatrixDisplay.from_predictions(y_test, predictions)
    plt.title(f'Confusion Matrix: {model_name}')
    plt.show()

# %%
from joblib import dump

dump(svm_model, "svm_model_best.joblib")
# Out:
# ['svm_model_best.joblib']
