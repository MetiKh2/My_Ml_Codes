# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('cardata.csv')
df=pd.DataFrame(data)
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.drop(columns='Car_Name',inplace=True)

# %%
# df.Year.to_list()
for i in range (df.Year.count()):
    df['Year'][i]=2019-df['Year'][i]
# df

# %%
df = df.rename(columns={'Year': 'Age'})
df
# Out:
#      Age  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      5           3.35           5.59       27000    Petrol      Dealer
# 1      6           4.75           9.54       43000    Diesel      Dealer
# 2      2           7.25           9.85        6900    Petrol      Dealer
# 3      8           2.85           4.15        5200    Petrol      Dealer
# 4      5           4.60           6.87       42450    Diesel      Dealer
# ..   ...            ...            ...         ...       ...         ...
# 296    3           9.50          11.60       33988    Diesel      Dealer
# 297    4           4.00           5.90       60000    Petrol      Dealer
# 298   10           3.35          11.00       87934    Petrol      Dealer
# 299    2          11.50          12.50        9000    Diesel      Dealer
# 300    3           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
df.describe(include='all')
# Out:
#                Age  Selling_Price  Present_Price     Kms_Driven Fuel_Type  \
# count   301.000000     301.000000     301.000000     301.000000       301
# unique         NaN            NaN            NaN            NaN         3
# top            NaN            NaN            NaN            NaN    Petrol
# freq           NaN            NaN            NaN            NaN       239
# mean      5.372093       4.661296       7.628472   36947.205980       NaN
# std       2.891554       5.082812       8.644115   38886.883882       NaN
# min       1.000000       0.100000       0.320000     500.000000       NaN
# 25%       3.000000       0.900000       1.200000   15000.000000       NaN
# 50%       5.000000       3.600000       6.400000   32000.000000       NaN
# 75%       7.000000       6.000000       9.900000   48767.000000       NaN
# max      16.000000      35.000000      92.600000  500000.000000       NaN
#
#        Seller_Type Transmission       Owner
# count          301          301  301.000000
# unique           2            2         NaN
# top         Dealer       Manual         NaN
# freq           195          261         NaN
# mean           NaN          NaN    0.043189
# std            NaN          NaN    0.247915
# min            NaN          NaN    0.000000
# 25%            NaN          NaN    0.000000
# 50%            NaN          NaN    0.000000
# 75%            NaN          NaN    0.000000
# max            NaN          NaN    3.000000

# %%
plt.scatter(df['Present_Price'],df['Selling_Price'])
plt.xlabel('Present_Price')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
plt.scatter(df['Kms_Driven'],df['Selling_Price'])
plt.xlabel('Kms_Driven')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
plt.scatter(df['Fuel_Type'],df['Selling_Price'])
plt.xlabel('Fuel_Type')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
plt.scatter(df['Seller_Type'],df['Selling_Price'])
plt.xlabel('Seller_Type')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
plt.scatter(df['Transmission'],df['Selling_Price'])
plt.xlabel('Transmission')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
plt.scatter(df['Owner'],df['Selling_Price'])
plt.xlabel('Owner')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
plt.scatter(df['Age'],df['Selling_Price'])
plt.xlabel('Age')
plt.ylabel('Selling_Price')
plt.grid()
plt.show()

# %%
print(df['Fuel_Type'].unique())
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']

# %%
def classify(data,col,values):
  for i,val in enumerate(values):
     data.loc[data[col] == val,[col]] =i

# %%
df2=df.copy()
classify(data=df2,col='Fuel_Type',values=['Petrol', 'Diesel', 'CNG'])
classify(data=df2,col='Seller_Type',values=['Dealer', 'Individual'])
classify(data=df2,col='Transmission',values=['Automatic', 'Manual'])

# %%
df2
# Out:
#      Age  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      5           3.35           5.59       27000         0           0
# 1      6           4.75           9.54       43000         1           0
# 2      2           7.25           9.85        6900         0           0
# 3      8           2.85           4.15        5200         0           0
# 4      5           4.60           6.87       42450         1           0
# ..   ...            ...            ...         ...       ...         ...
# 296    3           9.50          11.60       33988         1           0
# 297    4           4.00           5.90       60000         0           0
# 298   10           3.35          11.00       87934         0           0
# 299    2          11.50          12.50        9000         1           0
# 300    3           5.30           5.90        5464         0           0
#
#     Transmission  Owner
# 0              1      0
# 1              1      0
# 2              1      0
# 3              1      0
# 4              1      0
# ..           ...    ...
# 296            1      0
# 297            1      0
# 298            1      0
# 299            1      0
# 300            1      0
#
# [301 rows x 8 columns]

# %%
rs = np.random.RandomState(0)
corr = df2.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_45dde_row0_col0, #T_45dde_row1_col1, #T_45dde_row2_col2, #T_45dde_row3_col3, #T_45dde_row4_col4, #T_45dde_row5_col5, #T_45dde_row6_col6, #T_45dde_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_45dde_row0_col1, #T_45dde_row6_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_45dde_row0_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_45dde_row0_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_45dde_row0_col4, #T_45dde_row7_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_45dde_row0_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_45dde_row0_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_45dde_row0_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_45dde_row1_col0, #T_45dde_row1_col5, #T_45dde_row1_col6, #T_45dde_row1_col7, #T_45dde_row5_col1, #T_45dde_row5_col2, #T_45dde_row5_col4, #T_45dde_row6_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_45dde_row1_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_45dde_row1_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_45dde_row1_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_45dde_row2_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_45dde_row2_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_45dde_row2_col3, #T_45dde_row5_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_45dde_row2_col4 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_45dde_row2_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_45dde_row2_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_45dde_row2_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_45dde_row3_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_45dde_row3_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_45dde_row3_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_45dde_row3_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_45dde_row3_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_45dde_row3_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_45dde_row3_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_45dde_row4_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_45dde_row4_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_45dde_row4_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_45dde_row4_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_45dde_row4_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_45dde_row4_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_45dde_row4_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_45dde_row5_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_45dde_row5_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_45dde_row5_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_45dde_row6_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_45dde_row6_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_45dde_row6_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_45dde_row6_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_45dde_row6_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_45dde_row7_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_45dde_row7_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_45dde_row7_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_45dde_row7_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_45dde_row7_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_45dde_row7_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_45dde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45dde_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_45dde_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_45dde_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_45dde_level0_col3" class="col_heading level0 col3" >Kms_Driven</th>
#       <th id="T_45dde_level0_col4" class="col_heading level0 col4" >Fuel_Type</th>
#       <th id="T_45dde_level0_col5" class="col_heading level0 col5" >Seller_Type</th>
#       <th id="T_45dde_level0_col6" class="col_heading level0 col6" >Transmission</th>
#       <th id="T_45dde_level0_col7" class="col_heading level0 col7" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45dde_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_45dde_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_45dde_row0_col1" class="data row0 col1" >-0.236141</td>
#       <td id="T_45dde_row0_col2" class="data row0 col2" >0.047584</td>
#       <td id="T_45dde_row0_col3" class="data row0 col3" >0.524342</td>
#       <td id="T_45dde_row0_col4" class="data row0 col4" >-0.053643</td>
#       <td id="T_45dde_row0_col5" class="data row0 col5" >0.039896</td>
#       <td id="T_45dde_row0_col6" class="data row0 col6" >-0.000394</td>
#       <td id="T_45dde_row0_col7" class="data row0 col7" >0.182104</td>
#     </tr>
#     <tr>
#       <th id="T_45dde_level0_row1" class="row_heading level0 row1" >Selling_Price</th>
#       <td id="T_45dde_row1_col0" class="data row1 col0" >-0.236141</td>
#       <td id="T_45dde_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_45dde_row1_col2" class="data row1 col2" >0.878983</td>
#       <td id="T_45dde_row1_col3" class="data row1 col3" >0.029187</td>
#       <td id="T_45dde_row1_col4" class="data row1 col4" >0.509467</td>
#       <td id="T_45dde_row1_col5" class="data row1 col5" >-0.550724</td>
#       <td id="T_45dde_row1_col6" class="data row1 col6" >-0.367128</td>
#       <td id="T_45dde_row1_col7" class="data row1 col7" >-0.088344</td>
#     </tr>
#     <tr>
#       <th id="T_45dde_level0_row2" class="row_heading level0 row2" >Present_Price</th>
#       <td id="T_45dde_row2_col0" class="data row2 col0" >0.047584</td>
#       <td id="T_45dde_row2_col1" class="data row2 col1" >0.878983</td>
#       <td id="T_45dde_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_45dde_row2_col3" class="data row2 col3" >0.203647</td>
#       <td id="T_45dde_row2_col4" class="data row2 col4" >0.440415</td>
#       <td id="T_45dde_row2_col5" class="data row2 col5" >-0.512030</td>
#       <td id="T_45dde_row2_col6" class="data row2 col6" >-0.348715</td>
#       <td id="T_45dde_row2_col7" class="data row2 col7" >0.008057</td>
#     </tr>
#     <tr>
#       <th id="T_45dde_level0_row3" class="row_heading level0 row3" >Kms_Driven</th>
#       <td id="T_45dde_row3_col0" class="data row3 col0" >0.524342</td>
#       <td id="T_45dde_row3_col1" class="data row3 col1" >0.029187</td>
#       <td id="T_45dde_row3_col2" class="data row3 col2" >0.203647</td>
#       <td id="T_45dde_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_45dde_row3_col4" class="data row3 col4" >0.166801</td>
#       <td id="T_45dde_row3_col5" class="data row3 col5" >-0.101419</td>
#       <td id="T_45dde_row3_col6" class="data row3 col6" >-0.162510</td>
#       <td id="T_45dde_row3_col7" class="data row3 col7" >0.089216</td>
#     </tr>
#     <tr>
#       <th id="T_45dde_level0_row4" class="row_heading level0 row4" >Fuel_Type</th>
#       <td id="T_45dde_row4_col0" class="data row4 col0" >-0.053643</td>
#       <td id="T_45dde_row4_col1" class="data row4 col1" >0.509467</td>
#       <td id="T_45dde_row4_col2" class="data row4 col2" >0.440415</td>
#       <td id="T_45dde_row4_col3" class="data row4 col3" >0.166801</td>
#       <td id="T_45dde_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_45dde_row4_col5" class="data row4 col5" >-0.352415</td>
#       <td id="T_45dde_row4_col6" class="data row4 col6" >-0.080466</td>
#       <td id="T_45dde_row4_col7" class="data row4 col7" >-0.055705</td>
#     </tr>
#     <tr>
#       <th id="T_45dde_level0_row5" class="row_heading level0 row5" >Seller_Type</th>
#       <td id="T_45dde_row5_col0" class="data row5 col0" >0.039896</td>
#       <td id="T_45dde

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,KFold,cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
x=df2[['Age','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]
y=df2['Selling_Price'].values.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=41) 
df
# Out:
#      Age  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      5           3.35           5.59       27000    Petrol      Dealer
# 1      6           4.75           9.54       43000    Diesel      Dealer
# 2      2           7.25           9.85        6900    Petrol      Dealer
# 3      8           2.85           4.15        5200    Petrol      Dealer
# 4      5           4.60           6.87       42450    Diesel      Dealer
# ..   ...            ...            ...         ...       ...         ...
# 296    3           9.50          11.60       33988    Diesel      Dealer
# 297    4           4.00           5.90       60000    Petrol      Dealer
# 298   10           3.35          11.00       87934    Petrol      Dealer
# 299    2          11.50          12.50        9000    Diesel      Dealer
# 300    3           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
model=LinearRegression()

# %%
kfold_validation=KFold(2)

# %%
results=cross_val_score(model,x,y,cv=kfold_validation)
print(results)
print(np.mean(results))
# Out:
# [0.73673863 0.60162617]
# 0.669182399003115

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("Mean Squared Error",mean_squared_error(y_test,y_pred))
print("Mean Absolute Error",mean_absolute_error(y_test,y_pred))
print("R2 Score",r2_score(y_test,y_pred))
# Out:
# Mean Squared Error 8.388949211227004
# Mean Absolute Error 1.2677517591647791
# R2 Score 0.7634061838005076

# %%
print(model.intercept_,model.coef_)
# Out:
# [3.19127333] [[-2.86495223e-01  5.50860776e-01 -2.66390589e-05  1.53637706e+00
#   -5.51227250e-01 -3.74415915e-01 -8.03500417e-01]]

# %%
plt.scatter(x_test['Kms_Driven'],y_test)
plt.scatter(x_test['Kms_Driven'],y_pred,color='red')
