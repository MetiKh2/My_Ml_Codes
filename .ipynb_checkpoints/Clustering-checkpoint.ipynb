# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Customer_Data.csv')
df=pd.DataFrame(data)
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.drop(columns='CUST_ID',inplace=True)

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_1416d thead>tr>th {
#   text-align: left;
# }
# #T_1416d_row0_col0, #T_1416d_row1_col0, #T_1416d_row2_col0, #T_1416d_row3_col0, #T_1416d_row4_col0, #T_1416d_row5_col0, #T_1416d_row6_col0, #T_1416d_row7_col0, #T_1416d_row8_col0, #T_1416d_row9_col0, #T_1416d_row10_col0, #T_1416d_row11_col0, #T_1416d_row12_col0, #T_1416d_row13_col0, #T_1416d_row14_col0, #T_1416d_row15_col0, #T_1416d_row16_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_1416d_row0_col1, #T_1416d_row1_col1, #T_1416d_row2_col1, #T_1416d_row3_col1, #T_1416d_row4_col1, #T_1416d_row5_col1, #T_1416d_row6_col1, #T_1416d_row7_col1, #T_1416d_row8_col1, #T_1416d_row9_col1, #T_1416d_row10_col1, #T_1416d_row11_col1, #T_1416d_row12_col1, #T_1416d_row13_col1, #T_1416d_row14_col1, #T_1416d_row15_col1, #T_1416d_row16_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
# ...

# %%
print('Number of duplicated rows: ' , len(df[df.duplicated()]))
# Out:
# Number of duplicated rows:  0

# %%
from matplotlib.colors import ListedColormap

custom_cmap = ListedColormap(['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']) 
plt.figure(figsize=(22,4))
sns.heatmap((df.isna().sum()).to_frame(name='').T, annot=True,
            ).set_title('Count of Missing Values', fontsize=18)
plt.show()

# %%
import missingno as msno
import matplotlib.pyplot as plt
msno.bar(data)
plt.show()

# %%
df['CREDIT_LIMIT'].value_counts()
# Out:
# CREDIT_LIMIT
# 3000.000000    784
# 1500.000000    722
# 1200.000000    621
# 1000.000000    614
# 2500.000000    612
#               ...
# 3777.777778      1
# 650.000000       1
# 1450.000000      1
# 2350.000000      1
# 1833.333333      1
# Name: count, Length: 205, dtype: int64

# %%
# filling missing values of 'CREDIT_LIMIT' and 'MINIMUM_PAYMENTS' with mean

df['CREDIT_LIMIT']=df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())
df['MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())

# %%
#create histogram
df.hist(bins = 10, edgecolor = 'black', figsize = (15, 20))

#add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

#show plot
plt.show()

# %%
corr=df.corr()
fig = plt.figure(figsize=(15,12))
r = sns.heatmap(corr, cmap='Oranges', annot=True, fmt=".2f")
r.set_title("Correlation ")
# Out:
# Text(0.5, 1.0, 'Correlation ')

# %%
df_box = df.columns
i =  0
while i < len(df_box):
    fig = plt.figure(figsize = (25, 4), facecolor='burlywood')
    
    plt.subplot (1 , 2 , 1)
    box = sns.boxplot(x=df_box [i], data=df, palette="hot_r", width=0.5, dodge=True )
    box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
    box.set(xlabel=None)
    box.set_facecolor('white')
    plt.grid()
    i += 1

    if i < len(df_box):
        plt.subplot (1 , 2 , 2)
        box = sns.boxplot(x=df_box [i], data=df, palette="hot_r", width=0.5, dodge=True )
        box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
        box.set(xlabel=None)
        box.set_facecolor('white')
        plt.grid()
        i += 1

    plt.show()

# %%
df2=df[df['CASH_ADVANCE']<40000]
df2
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
df_box = df2.columns
i =  0
while i < len(df_box):
    fig = plt.figure(figsize = (25, 4), facecolor='burlywood')
    
    plt.subplot (1 , 2 , 1)
    box = sns.boxplot(x=df_box [i], data=df2, palette="hot_r", width=0.5, dodge=True )
    box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
    box.set(xlabel=None)
    box.set_facecolor('white')
    plt.grid()
    i += 1

    if i < len(df_box):
        plt.subplot (1 , 2 , 2)
        box = sns.boxplot(x=df_box [i], data=df2, palette="hot_r", width=0.5, dodge=True )
        box.set_title("Boxplot of Column " + df_box [i] , fontsize=18 , backgroundcolor = 'black',color='white')
        box.set(xlabel=None)
        box.set_facecolor('white')
        plt.grid()
        i += 1

    plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_features=scaler.fit_transform(df)

# %%
from sklearn.cluster import KMeans

vc=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42,n_init=10,max_iter=300)
    kmeans.fit(scaled_features)
    vc.append(kmeans.inertia_)
vc
# Out:
# [161100.00000000003,
#  136699.18487374962,
#  118584.96376330027,
#  106038.66757328893,
#  97165.36802031014,
#  90517.70161935191,
#  85246.79748061417,
#  80862.37129521195,
#  77538.65797486852,
#  72391.70957268511]

# %%
# plotting variance(vc) and clusters(i)

import matplotlib.pyplot as plt
plt.plot(range(1,11),vc)
plt.xticks(range(0,11))
plt.xlabel('no of clusters')
plt.ylabel('variance')
plt.title('no of clusters vs variance')
plt.show()

# %%
from kneed import DataGenerator, KneeLocator
kneedle = KneeLocator(range(1,11), vc, S=1.0, curve="convex", direction="decreasing")
kneedle.elbow
# Out:
# np.int64(3)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
silhouette_coeefficients=[]
for i in range(2,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42,n_init=10,max_iter=300)
    kmeans.fit(scaled_features)
    silhouette_coeefficients.append(silhouette_score(scaled_features,kmeans.labels_))
silhouette_coeefficients
# Out:
# [np.float64(0.19971171565683107),
#  np.float64(0.2718958137902729),
#  np.float64(0.19346481063646512),
#  np.float64(0.18780918527065116),
#  np.float64(0.19586403477469846),
#  np.float64(0.20622857736005437),
#  np.float64(0.21314001556331144),
#  np.float64(0.2078559701807468),
#  np.float64(0.2250396772160463)]

# %%
plt.plot(range(2,11),silhouette_coeefficients)

# %%
# model creation

kmeans=KMeans(n_clusters=3,init='k-means++',random_state=42)
kmeans.fit(df)
y_pred=kmeans.predict(df)
y_pred
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
df['cluster output']=y_pred
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
df['cluster output'].value_counts()
# Out:
# cluster output
# 1    6524
# 0    2292
# 2     134
# Name: count, dtype: int64

# %%
# seperating x(inputs) and y(output) from dataset 'a'

x=df.iloc[:,:-1]
y=df.iloc[:,-1]
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 8945    1
# 8946    1
# 8947    1
# 8948    1
# 8949    1
# Name: cluster output, Length: 8950, dtype: int32

# %%
x
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
# implementing train test split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
# Implementing classification model(Decision Tree)

from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0], dtype=int32)

# %%
from sklearn.metrics import classification_report,accuracy_score
print('the classificaton report is',classification_report(y_test,y_pred))
print('the accuracy score is',accuracy_score(y_test,y_pred))
# Out:
# the classificaton report is               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       663
#            1       0.98      0.99      0.99      1988
#            2       0.71      0.74      0.72        34
#
#     accuracy                           0.97      2685
#    macro avg       0.88      0.89      0.89      2685
# weighted avg       0.97      0.97      0.97      2685
#
# the accuracy score is 0.9728119180633147

# %%
plt.scatter(df[df['cluster output']==0]['BALANCE'], df[df['cluster output']==0]['PURCHASES'], s = 50, c = 'pink')
plt.scatter(df[df['cluster output']==1]['BALANCE'], df[df['cluster output']==1]['PURCHASES'], s = 50, c = 'red')
plt.scatter(df[df['cluster output']==2]['BALANCE'], df[df['cluster output']==2]['PURCHASES'], s = 50, c = 'green')

# %%
plt.scatter(df[df['cluster output']==0]['ONEOFF_PURCHASES'], df[df['cluster output']==0]['CASH_ADVANCE'], s = 50, c = 'pink')
plt.scatter(df[df['cluster output']==1]['ONEOFF_PURCHASES'], df[df['cluster output']==1]['CASH_ADVANCE'], s = 50, c = 'red')
plt.scatter(df[df['cluster output']==2]['ONEOFF_PURCHASES'], df[df['cluster output']==2]['CASH_ADVANCE'], s = 50, c = 'green')

# %%
plt.scatter(df[df['cluster output']==0]['CREDIT_LIMIT'], df[df['cluster output']==0]['PAYMENTS'], s = 50, c = 'pink')
plt.scatter(df[df['cluster output']==1]['CREDIT_LIMIT'], df[df['cluster output']==1]['PAYMENTS'], s = 50, c = 'red')
plt.scatter(df[df['cluster output']==2]['CREDIT_LIMIT'], df[df['cluster output']==2]['PAYMENTS'], s = 50, c = 'green')

# %%
plt.scatter(df[df['cluster output']==0]['MINIMUM_PAYMENTS'], df[df['cluster output']==0]['PAYMENTS'], s = 50, c = 'pink')
plt.scatter(df[df['cluster output']==1]['MINIMUM_PAYMENTS'], df[df['cluster output']==1]['PAYMENTS'], s = 50, c = 'red')
plt.scatter(df[df['cluster output']==2]['MINIMUM_PAYMENTS'], df[df['cluster output']==2]['PAYMENTS'], s = 50, c = 'green')

# %%
plt.scatter(df[df['cluster output']==0]['BALANCE_FREQUENCY'], df[df['cluster output']==0]['BALANCE'], s = 50, c = 'pink')
plt.scatter(df[df['cluster output']==1]['BALANCE_FREQUENCY'], df[df['cluster output']==1]['BALANCE'], s = 50, c = 'red')
plt.scatter(df[df['cluster output']==2]['BALANCE_FREQUENCY'], df[df['cluster output']==2]['BALANCE'], s = 50, c = 'green')

# %%
plt.scatter(df[df['cluster output']==0]['ONEOFF_PURCHASES'], df[df['cluster output']==0]['PURCHASES'], s = 50, c = 'pink')
plt.scatter(df[df['cluster output']==1]['ONEOFF_PURCHASES'], df[df['cluster output']==1]['PURCHASES'], s = 50, c = 'red')
plt.scatter(df[df['cluster output']==2]['ONEOFF_PURCHASES'], df[df['cluster output']==2]['PURCHASES'], s = 50, c = 'green')

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
from sklearn.metrics import silhouette_score
silhouette_coeefficients=[]
for k in range(2,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(df)
# Out:
# array([[3.39702083e+03, 9.40782480e-01, 1.58554385e+03, 9.91406005e+02,
#         5.94450760e+02, 2.10034921e+03, 5.40220724e-01, 3.17779708e-01,
#         3.85114850e-01, 2.10494418e-01, 5.74038462e+00, 2.21612762e+01,
#         9.00511562e+03, 2.87804272e+03, 1.56525077e+03, 1.34387630e-01,
#         1.17373252e+01],
#        [8.55827324e+02, 8.54369973e-01, 6.04761330e+02, 3.13008096e+02,
#         2.92051745e+02, 4.95257307e+02, 4.67800751e-01, 1.54229475e-01,
#         3.52499821e-01, 1.06805936e-01, 2.25367647e+00, 1.06801471e+01,
#         2.74978064e+03, 9.98149910e+02, 5.85698346e+02, 1.56935669e-01,
#         1.14335172e+01],
#        [4.79720357e+03, 9.08473866e-01, 1.04707237e+04, 7.39299015e+03,
#         3.07789769e+03, 5.38998332e+03, 7.37381261e-01, 5.82882687e-01,
#         5.92929851e-01, 2.29106075e-01, 9.18656716e+00, 8.37910448e+01,
#         1.24705224e+04, 1.79906949e+04, 2.46205952e+03, 3.26799679e-01,
#         1.18432836e+01]])
