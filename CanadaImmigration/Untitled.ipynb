# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
df=pd.read_excel('Canada.xlsx',sheet_name = 'Canada by Citizenship (2)')
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
#
#              RegName  DEV             DevName   1980  ...  2004  2005  2006  \
# 0      Southern Asia  902  Developing regions     16  ...  2978  3436  3009
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      196 non-null    object
#  1   Coverage  196 non-null    object
#  2   OdName    196 non-null    object
#  3   AREA      196 non-null    int64
#  4   AreaName  196 non-null    object
#  5   REG       196 non-null    int64
#  6   RegName   196 non-null    object
#  7   DEV       196 non-null    int64
#  8   DevName   196 non-null    object
#  9   1980      196 non-null    int64
#  10  1981      196 non-null    int64
#  11  1982      196 non-null    int64
#  12  1983      196 non-null    int64
#  13  1984      196 non-null    int64
#  14  1985      196 non-null    int64
#  15  1986      196 non-null    int64
#  16  1987      196 non-null    int64
#  17  1988      196 non-null    int64
#  18  1989      196 non-null    int64
#  19  1990      196 non-null    int64
# ...

# %%
df1=df.set_index('OdName')
df1
# Out:
#                       Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania         Immigrants  Foreigners   908   Europe   925  Southern Europe
# Algeria         Immigrants  Foreigners   903   Africa   912  Northern Africa
# American Samoa  Immigrants  Foreigners   909  Oceania   957        Polynesia
# Andorra         Immigrants  Foreigners   908   Europe   925  Southern Europe
# ...                    ...         ...   ...      ...   ...              ...
# Western Sahara  Immigrants  Foreigners   903   Africa   912  Northern Africa
# Yemen           Immigrants  Foreigners   935     Asia   922     Western Asia
# Zambia          Immigrants  Foreigners   903   Africa   910   Eastern Africa
# Zimbabwe        Immigrants  Foreigners   903   Africa   910   Eastern Africa
# Unknown         Immigrants  Foreigners   999    World   999            World
#
# ...

# %%
df1=df1.iloc[:,8:]
df1= pd.DataFrame(df1)
df1
# Out:
#                  1980   1981   1982   1983   1984   1985   1986   1987   1988  \
# OdName
# Afghanistan        16     39     39     47     71    340    496    741    828
# Albania             1      0      0      0      0      0      1      2      2
# Algeria            80     67     71     69     63     44     69    132    242
# American Samoa      0      1      0      0      0      0      0      1      0
# Andorra             0      0      0      0      0      0      2      0      0
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# Western Sahara      0      0      0      0      0      0      0      0      0
# Yemen               1      2      1      6      0     18      7     12      7
# Zambia             11     17     11      7     16      9     15     23     44
# Zimbabwe           72    114    102     44     32     29     43     68     99
# Unknown         44000  18078  16904  13635  14855  14368  13303  17304  22279
#
# ...

# %%
plt.plot(df1.loc['Afghanistan'])

# %%
total=[]
df['sum']=None
for i in range(len(df)):
    df['sum'][i]=sum(df.iloc[i,9:-1])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11364\793102587.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['sum'][i]=sum(df.iloc[i,9:-1])
# ...

# %%
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
#
#              RegName  DEV             DevName   1980  ...  2005  2006  2007  \
# 0      Southern Asia  902  Developing regions     16  ...  3436  3009  2652
# ...

# %%
df=df.sort_values(by='sum',ascending=False)

# %%
df
# Out:
#            Type    Coverage  \
# 79   Immigrants  Foreigners
# 36   Immigrants  Foreigners
# 183  Immigrants  Foreigners
# 195  Immigrants  Foreigners
# 136  Immigrants  Foreigners
# ..          ...         ...
# 123  Immigrants  Foreigners
# 149  Immigrants  Foreigners
# 109  Immigrants  Foreigners
# 191  Immigrants  Foreigners
# 131  Immigrants  Foreigners
#
#                                                 OdName  AREA AreaName   REG  \
# 79                                               India   935     Asia  5501
# 36                                               China   935     Asia   906
# 183  United Kingdom of Great Britain and Northern I...   908   Europe   924
# 195                                            Unknown   999    World   999
# 136                                        Philippines   935     Asia   920
# ..                                                 ...   ...      ...   ...
# 123                                      New Caledonia   909  Oceania   928
# ...

# %%
for i in range(12):
    plt.plot(df.iloc[i,9:-1])
    plt.title(df.iloc[i]['OdName'])
    plt.show()

# %%
iceland=df[df['OdName']=='Iceland'].iloc[:,9:-1].T
iceland[]
# Out:
#       78
# 1980  17
# 1981  33
# 1982  10
# 1983   9
# 1984  13
# 1985   6
# 1986  11
# 1987  11
# 1988   7
# 1989   3
# 1990   2
# 1991  11
# 1992  17
# 1993  15
# 1994  11
# 1995   9
# 1996  14
# 1997  11
# 1998  20
# 1999  17
# 2000   9
# 2001  26
# 2002  11
# 2003  17
# 2004  23
# 2005  10
# 2006   2
# 2007  15
# 2008  13
# 2009  15
# 2010  30
# 2011  38
# 2012  42
# 2013  72

# %%
plt.bar(iceland[''])
plt.title("immigration of iceland over years ")
plt.xlabel("num of immegrates")
plt.ylabel("years")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 plt.bar(iceland)
#       2 plt.title("immigration of iceland over years ")
#       3 plt.xlabel("num of immegrates")
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
np.arange(1980,2014,1)
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013])

# %%
df
# Out:
#            Type    Coverage  \
# 79   Immigrants  Foreigners
# 36   Immigrants  Foreigners
# 183  Immigrants  Foreigners
# 195  Immigrants  Foreigners
# 136  Immigrants  Foreigners
# ..          ...         ...
# 123  Immigrants  Foreigners
# 149  Immigrants  Foreigners
# 109  Immigrants  Foreigners
# 191  Immigrants  Foreigners
# 131  Immigrants  Foreigners
#
#                                                 OdName  AREA AreaName   REG  \
# 79                                               India   935     Asia  5501
# 36                                               China   935     Asia   906
# 183  United Kingdom of Great Britain and Northern I...   908   Europe   924
# 195                                            Unknown   999    World   999
# 136                                        Philippines   935     Asia   920
# ..                                                 ...   ...      ...   ...
# 123                                      New Caledonia   909  Oceania   928
# ...
