# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('eighteen_nineteen_university_datasets.csv',encoding='unicode_escape',names=['World Rank','Institution','Location','National Rank',
                              'Quality of Education','Alumni Employment','Quality of Faculty',
                             'Research Output','Quality Publications','Influence','Citations','Score'])
df=pd.DataFrame(data)
df.drop(index=0,inplace=True)
df
# Out:
#      World Rank                            Institution        Location  \
# 1             1                     Harvard University             USA
# 2             2                    Stanford University             USA
# 3             3  Massachusetts Institute of Technology             USA
# 4             4                University of Cambridge  United Kingdom
# 5             5                   University of Oxford  United Kingdom
# ...         ...                                    ...             ...
# 996         996                    Aga Khan University        Pakistan
# 997         997                 University of Calcutta           India
# 998         998                       K?chi University           Japan
# 999         999               Soonchunhyang University     South Korea
# 1000       1000              Capital Normal University           China
#
#      National Rank Quality of Education Alumni Employment Quality of Faculty  \
# ...

# %%
df.describe(include='all')
# Out:
#        World Rank                Institution Location National Rank  \
# count        1000                       1000     1000          1000
# unique       1000                       1000       61           213
# top          1000  Capital Normal University      USA             1
# freq            1                          1      213            61
#
#        Quality of Education Alumni Employment Quality of Faculty  \
# count                  1000              1000               1000
# unique                  404               492                221
# top                       -            > 1000                  -
# freq                    597               509                731
#
#        Research Output Quality Publications Influence Citations Score
# count             1000                 1000      1000      1000  1000
# unique             905                  892       830        75   195
# top             > 1000               > 1000    > 1000       898    70
# ...

# %%
df.dtypes
# Out:
# World Rank              object
# Institution             object
# Location                object
# National Rank           object
# Quality of Education    object
# Alumni Employment       object
# Quality of Faculty      object
# Research Output         object
# Quality Publications    object
# Influence               object
# Citations               object
# Score                   object
# dtype: object

# %%
df['Score']=pd.to_numeric(df['Score'])

# %%
df[df['Quality of Education']!="-"]['Quality of Education'].count(),df[df['Quality of Faculty']!="-"]['Quality of Faculty'].count()
df2=df.drop(columns=['Quality of Education',"Quality of Faculty"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1 to 1000
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   World Rank            1000 non-null   object
#  1   Institution           1000 non-null   object
#  2   Location              1000 non-null   object
#  3   National Rank         1000 non-null   object
#  4   Alumni Employment     1000 non-null   object
#  5   Research Output       1000 non-null   object
#  6   Quality Publications  1000 non-null   object
#  7   Influence             1000 non-null   object
#  8   Citations             1000 non-null   object
#  9   Score                 1000 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 78.3+ KB

# %%
plt.scatter(df['World Rank'],df['Score'])
plt.xticks(rotation=90)
plt.show()
